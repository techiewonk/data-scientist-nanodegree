# %% [markdown]
# # Stackoverflow survey data

# %% [markdown]
# ### Data Analysis Process
# 1. Business Understanding to define Problem statement.
# 1.  Data Understanding.
# 2.  Prepare Data.
# 3.  Data Modeling.
# 4.  Evaluate the Results
# 5.  Deploy.

# %% [markdown]
# ## Business Understanding to define Problem statement.

# %% [markdown]
# ***I want to setup software development business worldwide and hire developer from respective country. in that process I want to learn about technologies used by developers in software development. which country and tools I have to target based on satisfaction level of developer and lastly How much I have to pay for respective developer from respective countries ***

# %% [markdown]
# ### Problem Statement Includes
# - Which are the Most popular software development scenarios used by developers in year 2019 in different countries  ?
# - Job satisfaction ratio and career satisfaction with different coding languages in different countries ?
# - How education influence on the salary ?

# %% [markdown]
# ## Dataset and Data Understanding Solution Progress

# %% [markdown]
# ### Header for import

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import re
import collections
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['figure.dpi'] = 100
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'bbox_inches':None}
from plotnine import *
from feature_selector import FeatureSelector

# %% [markdown]
# ### Data import from Developer Survey

# %%
df_2019 = pd.read_csv(r'.\data\developer_survey_2019\survey_results_public.csv')

# %%
df_2018 = pd.read_csv(r'.\data\developer_survey_2018\survey_results_public.csv',low_memory=False)

# %%
df_2017 = pd.read_csv(r'.\data\developer_survey_2017\survey_results_public.csv',low_memory=False)

# %%
df_2019_schema  = pd.read_csv(r'.\data\developer_survey_2019\survey_results_schema.csv')

# %%
df_2018_schema  = pd.read_csv(r'.\data\developer_survey_2018\survey_results_schema.csv')

# %%
df_2017_schema  = pd.read_csv(r'.\data\developer_survey_2017\survey_results_schema.csv')

# %% [markdown]
# ### Data Understanding and Presentation

# %%
df_2019.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist              OpenSourcer                                         OpenSource                              Employment                 Country         Student                                            EdLevel UndergradMajor                                           EduOther OrgSize                                            DevType YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant                          JobSeek          LastHireDate LastInt FizzBuzz                                         JobFactors                                       ResumeUpdate CurrencySymbol CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests PurchaseHow PurchaseWhat               LanguageWorkedWith                           LanguageDesireNextYear DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0           1  I am a student who is learning to code      Yes                    Never  The quality of OSS and closed source software ...  Not employed, and not looking for work          United Kingdom              No                          Primary/elementary school            NaN  Taught yourself a new language, framework, or ...     NaN                                                NaN         4         10          NaN       NaN    NaN      NaN      NaN     NaN                              NaN                   NaN     NaN      NaN                                                NaN                                                NaN            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN  HTML/CSS;Java;JavaScript;Python  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1           2  I am a student who is learning to code       No  Less than once per year  The quality of OSS and closed source software ...      Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time  Secondary school (e.g. American high school, G...            NaN  Taken an online course in programming or softw...     NaN  Developer, desktop or enterprise applications;...       NaN         17          NaN       NaN    NaN      NaN      NaN     NaN  I am actively looking for a job  I've never had a job     NaN      NaN  Financial performance or funding status of the...  Something else changed (education, award, medi...            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN              C++;HTML/CSS;Python                      C++;HTML/CSS;JavaScript;SQL                NaN                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith MiscTechDesireNextYear                  DevEnviron    OpSys               Containers BlockchainOrg                                       BlockchainIs BetterLife                                  ITperson OffOn SocialMedia Extraversion ScreenName SOVisit1st                      SOVisitFreq                                          SOVisitTo        SOFindAnswer                     SOTimeSaved  SOHowMuchTime SOAccount                       SOPartFreq                                             SOJobs                             EntTeams         SOComm                            WelcomeChange                                       SONewContent   Age Gender Trans                Sexuality Ethnicity Dependents           SurveyLength                  SurveyEase
# 0       Django;Flask           Flask;jQuery            Node.js                Node.js  IntelliJ;Notepad++;PyCharm  Windows  I do not use containers           NaN                                                NaN        Yes  Fortunately, someone else has that title   Yes     Twitter       Online   Username       2017  A few times per month or weekly  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  31-60 minutes        No                              NaN  No, I didn't know that Stack Overflow had a jo...  No, and I don't know what those are        Neutral  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  14.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult
# 1             Django                 Django                NaN                    NaN                Atom;PyCharm  Windows  I do not use containers           NaN  Useful across many domains and could change ma...        Yes                                       Yes   Yes   Instagram       Online   Username       2017            Daily or almost daily  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  11-30 minutes       Yes  A few times per month or weekly  No, I knew that Stack Overflow had a job board...  No, and I don't know what those are  Yes, somewhat  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  19.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult

# %%
# df_2018.head(2)

# %%
# df_2017.head(2)

# %%
for col in df_2019.columns:
    print(col)
# Out:
# Respondent
# MainBranch
# Hobbyist
# OpenSourcer
# OpenSource
# Employment
# Country
# Student
# EdLevel
# UndergradMajor
# EduOther
# OrgSize
# DevType
# YearsCode
# Age1stCode
# YearsCodePro
# CareerSat
# JobSat
# MgrIdiot
# MgrMoney
# MgrWant
# JobSeek
# LastHireDate
# LastInt
# FizzBuzz
# JobFactors
# ResumeUpdate
# CurrencySymbol
# CurrencyDesc
# CompTotal
# CompFreq
# ConvertedComp
# WorkWeekHrs
# WorkPlan
# WorkChallenge
# WorkRemote
# WorkLoc
# ImpSyn
# CodeRev
# CodeRevHrs
# UnitTests
# PurchaseHow
# PurchaseWhat
# LanguageWorkedWith
# LanguageDesireNextYear
# DatabaseWorkedWith
# DatabaseDesireNextYear
# PlatformWorkedWith
# PlatformDesireNextYear
# WebFrameWorkedWith
# WebFrameDesireNextYear
# MiscTechWorkedWith
# MiscTechDesireNextYear
# DevEnviron
# OpSys
# Containers
# BlockchainOrg
# BlockchainIs
# BetterLife
# ITperson
# OffOn
# SocialMedia
# Extraversion
# ScreenName
# SOVisit1st
# SOVisitFreq
# SOVisitTo
# SOFindAnswer
# SOTimeSaved
# SOHowMuchTime
# SOAccount
# SOPartFreq
# SOJobs
# EntTeams
# SOComm
# WelcomeChange
# SONewContent
# Age
# Gender
# Trans
# Sexuality
# Ethnicity
# Dependents
# SurveyLength
# SurveyEase

# %%
for col in df_2017.columns:
    print(col)
# Out:
# Respondent
# Professional
# ProgramHobby
# Country
# University
# EmploymentStatus
# FormalEducation
# MajorUndergrad
# HomeRemote
# CompanySize
# CompanyType
# YearsProgram
# YearsCodedJob
# YearsCodedJobPast
# DeveloperType
# WebDeveloperType
# MobileDeveloperType
# NonDeveloperType
# CareerSatisfaction
# JobSatisfaction
# ExCoderReturn
# ExCoderNotForMe
# ExCoderBalance
# ExCoder10Years
# ExCoderBelonged
# ExCoderSkills
# ExCoderWillNotCode
# ExCoderActive
# PronounceGIF
# ProblemSolving
# BuildingThings
# LearningNewTech
# BoringDetails
# JobSecurity
# DiversityImportant
# AnnoyingUI
# FriendsDevelopers
# RightWrongWay
# UnderstandComputers
# SeriousWork
# InvestTimeTools
# WorkPayCare
# KinshipDevelopers
# ChallengeMyself
# CompetePeers
# ChangeWorld
# JobSeekingStatus
# HoursPerWeek
# LastNewJob
# AssessJobIndustry
# AssessJobRole
# AssessJobExp
# AssessJobDept
# AssessJobTech
# AssessJobProjects
# AssessJobCompensation
# AssessJobOffice
# AssessJobCommute
# AssessJobRemote
# AssessJobLeaders
# AssessJobProfDevel
# AssessJobDiversity
# AssessJobProduct
# AssessJobFinances
# ImportantBenefits
# ClickyKeys
# JobProfile
# ResumePrompted
# LearnedHiring
# ImportantHiringAlgorithms
# ImportantHiringTechExp
# ImportantHiringCommunication
# ImportantHiringOpenSource
# ImportantHiringPMExp
# ImportantHiringCompanies
# ImportantHiringTitles
# ImportantHiringEducation
# ImportantHiringRep
# ImportantHiringGettingThingsDone
# Currency
# Overpaid
# TabsSpaces
# EducationImportant
# EducationTypes
# SelfTaughtTypes
# TimeAfterBootcamp
# CousinEducation
# WorkStart
# HaveWorkedLanguage
# WantWorkLanguage
# HaveWorkedFramework
# WantWorkFramework
# HaveWorkedDatabase
# WantWorkDatabase
# HaveWorkedPlatform
# WantWorkPlatform
# IDE
# AuditoryEnvironment
# Methodology
# VersionControl
# CheckInCode
# ShipIt
# OtherPeoplesCode
# ProjectManagement
# EnjoyDebugging
# InTheZone
# DifficultCommunication
# CollaborateRemote
# MetricAssess
# EquipmentSatisfiedMonitors
# EquipmentSatisfiedCPU
# EquipmentSatisfiedRAM
# EquipmentSatisfiedStorage
# EquipmentSatisfiedRW
# InfluenceInternet
# InfluenceWorkstation
# InfluenceHardware
# InfluenceServers
# InfluenceTechStack
# InfluenceDeptTech
# InfluenceVizTools
# InfluenceDatabase
# InfluenceCloud
# InfluenceConsultants
# InfluenceRecruitment
# InfluenceCommunication
# StackOverflowDescribes
# StackOverflowSatisfaction
# StackOverflowDevices
# StackOverflowFoundAnswer
# StackOverflowCopiedCode
# StackOverflowJobListing
# StackOverflowCompanyPage
# StackOverflowJobSearch
# StackOverflowNewQuestion
# StackOverflowAnswer
# StackOverflowMetaChat
# StackOverflowAdsRelevant
# StackOverflowAdsDistracting
# StackOverflowModeration
# StackOverflowCommunity
# StackOverflowHelpful
# StackOverflowBetter
# StackOverflowWhatDo
# StackOverflowMakeMoney
# Gender
# HighestEducationParents
# Race
# SurveyLong
# QuestionsInteresting
# QuestionsConfusing
# InterestedAnswers
# Salary
# ExpectedSalary

# %% [markdown]
# ### Selecting last year for analysis

# %%
df_country_count = df_2019.groupby(['Country'])['Respondent'].count().sort_values(ascending=False)
df_country_count
# Out:
# Country
# United States                                20949
# India                                         9061
# Germany                                       5866
# United Kingdom                                5737
# Canada                                        3395
# France                                        2391
# Brazil                                        1948
# Poland                                        1922
# Australia                                     1903
# Netherlands                                   1852
# Russian Federation                            1694
# Spain                                         1604
# Italy                                         1576
# Sweden                                        1274
# Switzerland                                    978
# Israel                                         952
# Turkey                                         949
# Pakistan                                       923
# Ukraine                                        868
# Austria                                        839
# Czech Republic                                 764
# Romania                                        760
# Iran                                           738
# Belgium                                        727
# China                                          664
# Bulgaria                                       659
# Mexico                                         642
# South Africa                                   627
# Denmark                                        617
# Bangladesh                                     605
# Norway                                         574
# Greece                                         556
# Argentina                                      553
# Finland                                        546
# Portugal                                       525
# New Zealand                                    524
# Nigeria                                        522
# Hungary                                        513
# Indonesia                                      507
# Ireland                                        501
# Serbia                                         402
# Japan                                          391
# Philippines                                    381
# Sri Lanka                                      372
# Egypt                                          323
# Colombia                                       313
# Singapore                                      303
# Malaysia                                       299
# Slovenia                                       298
# Croatia                                        260
# Slovakia                                       260
# Kenya                                          249
# Lithuania                                      248
# Nepal                                          237
# Viet Nam                                       231
# Thailand                                       214
# Chile                                          206
# Belarus                                        202
# Estonia                                        195
# Hong Kong (S.A.R.)                             188
# Taiwan                                         187
# South Korea                                    160
# United Arab Emirates                           158
# Morocco                                        155
# Latvia                                         136
# Other Country (Not Listed Above)               136
# Algeria                                        134
# Peru                                           130
# Tunisia                                        130
# Lebanon                                        120
# Uruguay                                        111
# Bosnia and Herzegovina                         108
# Saudi Arabia                                    98
# Dominican Republic                              97
# Venezuela, Bolivarian Republic of...            88
# Armenia                                         86
# Albania                                         86
# Ghana                                           84
# Costa Rica                                      84
# Ecuador                                         82
# Georgia                                         80
# Uganda                                          72
# El Salvador                                     67
# Guatemala                                       67
# Malta                                           65
# Jordan                                          65
# Kazakhstan                                      64
# Cyprus                                          64
# Luxembourg                                      61
# The former Yugoslav Republic of Macedonia       54
# Myanmar                                         52
# Ethiopia                                        52
# Paraguay                                        52
# Cameroon                                        51
# Iceland                                         49
# Azerbaijan                                      49
# Afghanistan                                     44
# Republic of Moldova                             43
# Sudan                                           42
# Iraq                                            39
# Zimbabwe                                        39
# Uzbekistan                                      39
# Republic of Korea                               39
# Bolivia                                         36
# Côte d'Ivoire                                   34
# Panama                                          33
# United Republic of Tanzania                     32
# Nicaragua                                       30
# Cuba                                            30
# Cambodia                                        30
# Syrian Arab Republic                            29
# Jamaica                                         28
# Honduras                                        27
# Mauritius                                       26
# Senegal                                         21
# Kuwait                                          20
# Trinidad and Tobago                             19
# Yemen                                           19
# Kyrgyzstan                                      19
# Bahrain                                         18
# Mongolia                                        17
# Montenegro                                      17
# Madagascar                                      15
# Maldives                                        13
# Somalia                                         13
# Qatar                                           13
# Rwanda                                          12
# Zambia                                          12
# Oman                                            11
# Libyan Arab Jamahiriya                          10
# Antigua and Barbuda                              9
# Swaziland                                        8
# Mozambique                                       7
# Tajikistan                                       7
# Congo, Republic of the...                        7
# Mauritania                                       7
# Turkmenistan                                     7
# Democratic Republic of the Congo                 7
# Andorra                                          7
# Fiji                                             5
# Benin                                            5
# Namibia                                          5
# Haiti                                            5
# Botswana                                         5
# Angola                                           5
# Burkina Faso                                     4
# Monaco                                           4
# Togo                                             4
# Lao People's Democratic Republic                 3
# Guyana                                           3
# Barbados                                         3
# Liechtenstein                                    3
# Bahamas                                          3
# Burundi                                          3
# Guinea                                           3
# Mali                                             3
# Cape Verde                                       3
# Lesotho                                          3
# Democratic People's Republic of Korea            3
# Belize                                           3
# Malawi                                           2
# Liberia                                          2
# Sierra Leone                                     2
# Bhutan                                           2
# Seychelles                                       2
# San Marino                                       2
# Gabon                                            2
# Djibouti                                         2
# Brunei Darussalam                                1
# Timor-Leste                                      1
# North Korea                                      1
# Chad                                             1
# Tonga                                            1
# Sao Tome and Principe                            1
# Saint Vincent and the Grenadines                 1
# Saint Kitts and Nevis                            1
# Papua New Guinea                                 1
# Dominica                                         1
# Niger                                            1
# Name: Respondent, dtype: int64

# %%
df_country_list = [
'United Kingdom', 'United States', 'Canada', 'India', 'Germany', 'Australia', 'Russian Federation', 'Brazil', 'Spain', 'France', 'Netherlands'
]

# %%
# Attributes list
target_attributes = [
    # Background
    'Country',
    'YearsCode',
    'DevType',
    'YearsCodePro',
    'CareerSat',
    'Gender',
    # Technologies
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'DatabaseWorkedWith',
    'DatabaseDesireNextYear',
    'PlatformWorkedWith',
    'PlatformDesireNextYear',
    'OpSys',
    'Sexuality',
    'DevType'
]

# %% [markdown]
# ## Most popular software development scenarios used by developers in year 2019 in different countries ?

# %% [markdown]
# ### Prepare Data

# %% [markdown]
# ### filter by countries

# %%
df_2019_top = df_2019[df_2019.Country.isin(df_country_list)] # filter by countries
df_2019_top
# Out:
#        Respondent                                         MainBranch Hobbyist                                        OpenSourcer                                         OpenSource                              Employment         Country         Student                                            EdLevel                                     UndergradMajor                                           EduOther                   OrgSize                                            DevType YearsCode Age1stCode      YearsCodePro              CareerSat                 JobSat            MgrIdiot MgrMoney                 MgrWant                                            JobSeek          LastHireDate                                            LastInt FizzBuzz                                         JobFactors                                       ResumeUpdate CurrencySymbol          CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs                                           WorkPlan  \
# 0               1             I am a student who is learning to code      Yes                                              Never  The quality of OSS and closed source software ...  Not employed, and not looking for work  United Kingdom              No                          Primary/elementary school                                                NaN  Taught yourself a new language, framework, or ...                       NaN                                                NaN         4         10               NaN                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 3               4                     I am a developer by profession       No                                              Never  The quality of OSS and closed source software ...                      Employed full-time   United States              No           Bachelor’s degree (BA, BS, B.Eng., etc.)  Computer science, computer engineering, or sof...  Taken an online course in programming or softw...      100 to 499 employees                              Developer, full-stack         3         16  Less than 1 year         Very satisfied     Slightly satisfied      Very confident       No                Not sure       I am not interested in new job opportunities  Less than a year ago  Write code by hand (e.g., on a whiteboard);Int...       No  Languages, frameworks, and other technologies ...                   I was preparing for a job search            USD  United States dollar    61000.0   Yearly        61000.0         80.0  There's no schedule or spec; I work on what se...
# 5               6  I am not primarily a developer, but I write co...      Yes                                              Never  The quality of OSS and closed source software ...                      Employed full-time          Canada              No           Bachelor’s degree (BA, BS, B.Eng., etc.)                          Mathematics or statistics  Taken an online course in programming or softw...                       NaN  Data or business analyst;Data scientist or mac...        13         15                 3         Very satisfied     Slightly satisfied      Very confident       No                     Yes       I am not interested in new job opportunities         1-2 years ago  Write any code;Complete a take-home project;In...       No  Financial performance or funding status of the...  I heard about a job opportunity (from a recrui...            CAD       Canadian dollar    40000.0  Monthly       366420.0         15.0  There's no schedule or spec; I work on what se...
# 7               8                        I code primarily as a hobby      Yes                            Less than once per year  OSS is, on average, of HIGHER quality than pro...      Not employed, but looking for work           India             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)  Computer science, computer engineering, or sof...  Taught yourself a new language, framework, or ...                       NaN     Developer, back-end;Engineer, site reliability         8         16               NaN                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 9              10                     I am a developer by profession      Yes                         Once a month or more often  OSS is, on average, of HIGHER quality than pro...                      Employed full-time           India              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)                                                NaN                                                NaN  10,000 or more employees  Data or business analyst;Data scientist or mac...        12         20                10  Slightly dissatisfied  Slightly dissatisfied  Somewhat confident      Yes                     Yes  I’m not actively looking, but I am open to new...         3-4 years ago                                                NaN       No  Languages, frameworks, and other technologies ...                                                NaN            INR          Indian rupee   950000.0   Yearly        13293.0         70.0  There's no schedule or spec; I work on what se...
# ...           ...                                                ...      ...                                                ...                                                ...                                     ...             ...             ...                                                ...                                                ...                                                ...                       ...                                                ...       ...        ...               ...                    ...                    ...                 ...      ...                     ...                                                ...                   ...                                                ...      ...                                                ...                                                ...            ...                   ...        ...      ...            ...          ...                                                ...
# 88870       87352                                                NaN      Yes                            Less than once per year                                                NaN  Not employed, and not looking for work     Netherlands              No           Bachelor’s degree (BA, BS, B.Eng., etc.)  Computer science, computer engineering, or sof...                                                NaN                       NaN                                                NaN        40         19               NaN                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 88876       88212                                                NaN       No                            Less than once per year  OSS is, on average, of HIGHER quality than pro...                      Employed full-time           Spain              No  Secondary school (e.g. American high school, G...                                                NaN  Taught yourself a new language, framework, or ...        10 to 19 employees  Designer;Developer, front-end;Developer, full-...        18          7                15                    NaN                    NaN  Somewhat confident      Yes  I am already a manager                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 88877       88282                                                NaN      Yes                         Once a month or more often  The quality of OSS and closed source software ...      Not employed, but looking for work   United States              No  Some college/university study without earning ...  Computer science, computer engineering, or sof...  Taught yourself a new language, framework, or ...                       NaN  Developer, back-end;Developer, desktop or ente...        38         10                38                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 88878       88377                                                NaN      Yes  Less than once a month but more than once per ...  The quality of OSS and closed source software ...  Not employed, and not looking for work          Canada              No                          Primary/elementary school                                                NaN  Taught yourself a new language, framework, or ...                       NaN                                                NaN       NaN        NaN               NaN                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
# 88882       88863                                                NaN      Yes                            Less than once per year  OSS is, on average, of HIGHER quality than pro...  Not employed, and not looking for work           Spain  Yes, full-time                 Professional degree (JD, MD, etc.)  Computer science, computer engineering, or sof...  Taken an online course in programming or softw...                       NaN                                                NaN         8         11                 3                    NaN                    NaN                 NaN      NaN                     NaN                                                NaN                   NaN                                                NaN      NaN                                                NaN                                                NaN            NaN                   NaN        NaN      NaN            NaN          NaN                                                NaN
#
#       WorkChallenge                        WorkRemote WorkLoc                  ImpSyn                                  CodeRev  CodeRevHrs                                          UnitTests                                        PurchaseHow                   PurchaseWhat                                 LanguageWorkedWith                             LanguageDesireNextYear                                 DatabaseWorkedWith                             DatabaseDesireNextYear                           PlatformWorkedWith                             PlatformDesireNextYear                                 WebFrameWorkedWith                             WebFrameDesireNextYear                 MiscTechWorkedWith                             MiscTechDesireNextYear                                         DevEnviron        OpSys                                         Containers                            BlockchainOrg                                       BlockchainIs BetterLife  \
# 0               NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN                    HTML/CSS;Java;JavaScript;Python    C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL                                             SQLite                                              MySQL                                MacOS;Windows                            Android;Arduino;Windows                                       Django;Flask                                       Flask;jQuery                            Node.js                                            Node.js                         IntelliJ;Notepad++;PyCharm      Windows                            I do not use containers                                      NaN                                                NaN        Yes
# 3               NaN  Less than once per month / Never    Home  A little below average                                       No         NaN                          No, but I think we should  Developers typically have the most influence o...  I have little or no influence                                C;C++;C#;Python;SQL                                C;C#;JavaScript;SQL                                       MySQL;SQLite                                       MySQL;SQLite                                Linux;Windows                                      Linux;Windows                                                NaN                                                NaN                               .NET                                               .NET       Eclipse;Vim;Visual Studio;Visual Studio Code      Windows                            I do not use containers                               Not at all  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5               NaN             A few days each month    Home  A little above average                                       No         NaN  Yes, it's not part of our process but the deve...                                           Not sure  I have little or no influence                                         Java;R;SQL                                   Python;Scala;SQL                                 MongoDB;PostgreSQL                                         PostgreSQL  Android;Google Cloud Platform;Linux;Windows        Android;Google Cloud Platform;Linux;Windows                                                NaN                                                NaN                             Hadoop                  Hadoop;Pandas;TensorFlow;Unity 3D  Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows                            I do not use containers                               Not at all                                                NaN         No
# 7               NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...  Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...  Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...  Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...          AWS;Docker;Heroku;Linux;MacOS;Slack  Android;Arduino;AWS;Docker;Google Cloud Platfo...                      Express;Flask;React.js;Spring               Django;Express;Flask;React.js;Vue.js              Hadoop;Node.js;Pandas  Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...  Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based  Development;Testing;Production;Outside of work...                                      NaN  Useful across many domains and could change ma...        Yes
# 9               NaN             A few days each month    Home       Far above average  Yes, because I see value in code review         4.0                      Yes, it's part of our process                                                NaN                            NaN                      C#;Go;JavaScript;Python;R;SQL               C#;Go;JavaScript;Kotlin;Python;R;SQL  Elasticsearch;MongoDB;Microsoft SQL Server;MyS...         Elasticsearch;MongoDB;Microsoft SQL Server                                Linux;Windows                 Android;Linux;Raspberry Pi;Windows  Angular/Angular.js;ASP.NET;Django;Express;Flas...  Angular/Angular.js;ASP.NET;Django;Express;Flas...  .NET;Node.js;Pandas;Torch/PyTorch              .NET;Node.js;TensorFlow;Torch/PyTorch  Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows                                                NaN                               Not at all  Useful for immutable record keeping outside of...         No
# ...             ...                               ...     ...                     ...                                      ...         ...                                                ...                                                ...                            ...                                                ...                                                ...                                                ...                                                ...                                          ...                                                ...                                                ...                                                ...                                ...                                                ...                                                ...          ...                                                ...                                      ...                                                ...        ...
# 88870           NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN                                         C;C++;Java                                                NaN                                    Firebase;SQLite                                                NaN                              Android;Windows                                                NaN                                                NaN                                                NaN                                NaN                                                NaN          Android Studio;Sublime Text;Visual Studio      Windows                            I do not use containers                                      NaN                                                NaN         No
# 88876           NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN                         HTML/CSS;JavaScript;Python                                         JavaScript                                   MySQL;PostgreSQL                                         PostgreSQL                                          NaN                                            Arduino                                    Django;React.js                                    Django;React.js                                NaN                                                NaN                            Atom;Visual Studio Code        MacOS                            I do not use containers  Non-currency applications of blockchain  Useful for immutable record keeping outside of...         No
# 88877           NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...  Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript...                                                NaN                                                NaN                                        Linux                                 Linux;Raspberry Pi                                           React.js                                             Vue.js                            Node.js                                            Ansible                                                Vim  Linux-based                            I do not use containers                                      NaN                  An irresponsible use of resources         No
# 88878           NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN                      HTML/CSS;JavaScript;Other(s):  C++;HTML/CSS;JavaScript;SQL;WebAssembly;Other(s):                                    Firebase;SQLite                              Firebase;MySQL;SQLite                                        Linux                        Google Cloud Platform;Linux                                             jQuery                                      jQuery;Vue.js                            Node.js                React Native;Unity 3D;Unreal Engine              Atom;Visual Studio;Visual Studio Code      Windows                            I do not use containers                                      NaN  Useful across many domains and could change ma...        Yes
# 88882           NaN                               NaN     NaN                     NaN                                      NaN         NaN                                                NaN                                                NaN                            NaN  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...       C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift        DynamoDB;MariaDB;Microsoft SQL Server;MySQL                        MariaDB;MySQL;Oracle;SQLite                    iOS;Linux;MacOS;WordPress  Android;AWS;Google Cloud Platform;IBM Cloud or...                             Django;jQuery;React.js                                             Django             Unity 3D;Unreal Engine                                                NaN  Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based                                         Production                                      NaN  Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#                                        ITperson  OffOn               SocialMedia              Extraversion   ScreenName        SOVisit1st                      SOVisitFreq                                          SOVisitTo             SOFindAnswer                         SOTimeSaved  SOHowMuchTime                  SOAccount                                         SOPartFreq                                             SOJobs                                           EntTeams           SOComm                             WelcomeChange                                       SONewContent   Age Gender Trans                Sexuality                                          Ethnicity Dependents           SurveyLength                  SurveyEase
# 0      Fortunately, someone else has that title    Yes                   Twitter                    Online     Username              2017  A few times per month or weekly  Find answers to specific questions;Learn how t...       3-5 times per week      Stack Overflow was much faster  31-60 minutes                         No                                                NaN  No, I didn't know that Stack Overflow had a jo...                No, and I don't know what those are          Neutral   Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  14.0    Man    No  Straight / Heterosexual                                                NaN         No  Appropriate in length  Neither easy nor difficult
# 3                                          SIGH    Yes                    Reddit  In real life (in person)     Username              2014            Daily or almost daily  Find answers to specific questions;Pass the ti...       1-2 times per week      Stack Overflow was much faster  31-60 minutes                        Yes                Less than once per month or monthly                                                Yes                No, and I don't know what those are   No, not really   Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  22.0    Man    No  Straight / Heterosexual                       White or of European descent         No  Appropriate in length                        Easy
# 5                                           Yes     No                   YouTube  In real life (in person)        Login              2011  A few times per month or weekly                 Find answers to specific questions  Less than once per week  Stack Overflow was slightly faster    60+ minutes                        Yes  I have never participated in Q&A on Stack Over...  No, I knew that Stack Overflow had a job board...                No, and I don't know what those are   No, not really   Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  28.0    Man    No  Straight / Heterosexual                                         East Asian         No               Too long  Neither easy nor difficult
# 7                                          SIGH    Yes                   YouTube  In real life (in person)       Handle              2012             A few times per week  Find answers to specific questions;Learn how t...  Less than once per week  Stack Overflow was slightly faster  11-30 minutes                        Yes                Less than once per month or monthly                                                Yes                No, and I don't know what those are  Yes, definitely     A lot more welcome now than last year  Tech articles written by other developers;Indu...  24.0    Man    No  Straight / Heterosexual                                                NaN        NaN  Appropriate in length  Neither easy nor difficult
# 9                                           Yes    Yes                   YouTube                   Neither  Screen Name               NaN           Multiple times per day  Find answers to specific questions;Get a sense...       3-5 times per week            They were about the same            NaN                        Yes                    A few times per month or weekly                                                Yes                No, and I don't know what those are    Yes, somewhat  Somewhat less welcome now than last year  Tech articles written by other developers;Tech...   NaN    NaN   NaN                      NaN                                                NaN        Yes               Too long                   Difficult
# ...                                         ...    ...                       ...                       ...          ...               ...                              ...                                                ...                      ...                                 ...            ...                        ...                                                ...                                                ...                                                ...              ...                                       ...                                                ...   ...    ...   ...                      ...                                                ...        ...                    ...                         ...
# 88870                                       NaN    NaN                   YouTube                       NaN          NaN              2008           Multiple times per day  Find answers to specific questions;Learn how t...                      NaN                                 NaN            NaN  Not sure / can't remember                                                NaN                                                Yes  No, I've heard of them, but I am not part of a...          Neutral   Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  59.0    Man    No                      NaN                                                NaN         No                    NaN                         NaN
# 88876                                      SIGH     No                  WhatsApp  In real life (in person)     Username              2008             A few times per week                 Find answers to specific questions      6-10 times per week  Stack Overflow was slightly faster   0-10 minutes                        Yes  I have never participated in Q&A on Stack Over...  No, I didn't know that Stack Overflow had a jo...                No, and I don't know what those are   No, not at all                                       NaN  Tech articles written by other developers;Indu...  40.0    Man    No  Straight / Heterosexual                       White or of European descent         No  Appropriate in length                        Easy
# 88877                                       NaN    Yes  I don't use social media  In real life (in person)     Username  I don't remember  A few times per month or weekly                 Find answers to specific questions       1-2 times per week            They were about the same            NaN                        Yes  I have never participated in Q&A on Stack Over...                                                Yes                No, and I don't know what those are   No, not really   Just as welcome now as I felt last year                                                NaN   NaN    Man    No  Straight / Heterosexual                                                NaN         No              Too short  Neither easy nor difficult
# 88878                                       Yes  What?                   YouTube                       NaN     Username  I don't remember             A few times per week  Find answers to specific questions;Learn how t...       3-5 times per week  Stack Overflow was slightly faster  11-30 minutes                        Yes  I have never participated in Q&A on Stack Over...  No, I knew that Stack Overflow had a job board...  No, I've heard of them, but I am not part of a...   No, not at all                                       NaN  Tech articles written by other developers;Tech...   NaN    Man    No                      NaN                                                NaN         No  Appropriate in length                        Easy
# 88882                                  Also Yes    Yes                  WhatsApp  In real life (in person)          NaN              2012            Daily or almost daily  Find answers to specific questions;Learn how t...      6-10 times per week      Stack Overflow was much faster  11-30 minutes                        Yes                    A few times per month or weekly                                                Yes  No, I've heard of them, but I am not part of a...    Yes, somewhat  Somewhat less welcome now than last year  Tech articles written by other developers;Indu...  18.0    Man    No  Straight / Heterosexual  Hispanic or Latino/Latina;White or of European...         No  Appropriate in length                        Easy
#
# [56400 rows x 85 columns]

# %% [markdown]
# ### filter by attributes

# %%
df_2019_top_filterd = df_2019_top[target_attributes] # filter by attributes
df_2019_top_filterd.head()
# Out:
#           Country YearsCode                                            DevType      YearsCodePro              CareerSat Gender                                 LanguageWorkedWith                             LanguageDesireNextYear                                 DatabaseWorkedWith                             DatabaseDesireNextYear                           PlatformWorkedWith                             PlatformDesireNextYear        OpSys                Sexuality                                            DevType
# 0  United Kingdom         4                                                NaN               NaN                    NaN    Man                    HTML/CSS;Java;JavaScript;Python    C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL                                             SQLite                                              MySQL                                MacOS;Windows                            Android;Arduino;Windows      Windows  Straight / Heterosexual                                                NaN
# 3   United States         3                              Developer, full-stack  Less than 1 year         Very satisfied    Man                                C;C++;C#;Python;SQL                                C;C#;JavaScript;SQL                                       MySQL;SQLite                                       MySQL;SQLite                                Linux;Windows                                      Linux;Windows      Windows  Straight / Heterosexual                              Developer, full-stack
# 5          Canada        13  Data or business analyst;Data scientist or mac...                 3         Very satisfied    Man                                         Java;R;SQL                                   Python;Scala;SQL                                 MongoDB;PostgreSQL                                         PostgreSQL  Android;Google Cloud Platform;Linux;Windows        Android;Google Cloud Platform;Linux;Windows      Windows  Straight / Heterosexual  Data or business analyst;Data scientist or mac...
# 7           India         8     Developer, back-end;Engineer, site reliability               NaN                    NaN    Man  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...  Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...  Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...  Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...          AWS;Docker;Heroku;Linux;MacOS;Slack  Android;Arduino;AWS;Docker;Google Cloud Platfo...  Linux-based  Straight / Heterosexual     Developer, back-end;Engineer, site reliability
# 9           India        12  Data or business analyst;Data scientist or mac...                10  Slightly dissatisfied    NaN                      C#;Go;JavaScript;Python;R;SQL               C#;Go;JavaScript;Kotlin;Python;R;SQL  Elasticsearch;MongoDB;Microsoft SQL Server;MyS...         Elasticsearch;MongoDB;Microsoft SQL Server                                Linux;Windows                 Android;Linux;Raspberry Pi;Windows      Windows                      NaN  Data or business analyst;Data scientist or mac...

# %%
df_2019_top_filterd[['LanguageWorkedWith', 'DatabaseWorkedWith', 'PlatformWorkedWith' ]].sample(10)
# Out:
#                                       LanguageWorkedWith                     DatabaseWorkedWith                                PlatformWorkedWith
# 51056  Bash/Shell/PowerShell;C;C++;C#;HTML/CSS;Java;J...                       MySQL;PostgreSQL                              Docker;Linux;Windows
# 11870  Bash/Shell/PowerShell;C;HTML/CSS;Java;JavaScri...                                  MySQL                                           Android
# 5650               Go;HTML/CSS;JavaScript;PHP;TypeScript                       MySQL;PostgreSQL                                               NaN
# 66101                   Bash/Shell/PowerShell;C;Java;SQL  Microsoft SQL Server;MySQL;PostgreSQL                                   AWS;Linux;MacOS
# 64655      Bash/Shell/PowerShell;Java;Python;R;Scala;SQL     MongoDB;Microsoft SQL Server;MySQL                                               NaN
# 54886  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...            Elasticsearch;MongoDB;MySQL  Android;AWS;Docker;Linux;Slack;Windows;WordPress
# 45935     C++;HTML/CSS;Java;JavaScript;Python;TypeScript                   Microsoft SQL Server                                               NaN
# 18973         Assembly;C;HTML/CSS;Java;Objective-C;Swift                           MySQL;SQLite                                       Android;iOS
# 68035  Assembly;Bash/Shell/PowerShell;C++;HTML/CSS;Ja...                 DynamoDB;Elasticsearch                                      Docker;Linux
# 47549            Bash/Shell/PowerShell;HTML/CSS;Java;SQL                   Microsoft SQL Server                     Linux;Slack;Windows;WordPress

# %%
df_2019_top_filterd[['LanguageWorkedWith', 'DatabaseWorkedWith', 'PlatformWorkedWith']].isnull().mean()
# Out:
# LanguageWorkedWith    0.010727
# DatabaseWorkedWith    0.148457
# PlatformWorkedWith    0.091454
# dtype: float64

# %%
# Count the technology usage in each country, return a nested dictionary 
# in the form: {countyname: {tech1: count1, tech2: count2, ....}, .......}
def getStatistics(df, tech):
    """ Given the dataframe, counting the technology usage for each country
    
    Args:
        df: dataframe
        tech: Language, Database, Platform, or Framework
    
    Returns:
        A dictionary containing the technology usage for each country
        
    """
    statistics = {}
    WorkedWith = tech + 'WorkedWith'
    for index, row in df[['Country', WorkedWith]].iterrows():
        # add countries to the list if not exists
        if row['Country'] not in statistics:
            statistics[row['Country']] = {}
        # Technology count
        if row[WorkedWith] is not np.nan:
            for tar in row[WorkedWith].split(';'):
                statistics[row['Country']][tar] = statistics[row['Country']].get(tar, 0) + 1 

    return statistics

# %%
# Counting the tech usage
language_statistics = getStatistics(df_2019_top_filterd, 'Language')
platform_statistics = getStatistics(df_2019_top_filterd, 'Platform')
database_statistics = getStatistics(df_2019_top_filterd, 'Database')

# %%
# keys: the countries 
language_statistics.keys()
# Out:
# dict_keys(['United Kingdom', 'United States', 'Canada', 'India', 'Germany', 'Australia', 'Russian Federation', 'Brazil', 'Spain', 'France', 'Netherlands'])

# %%
# values: the technology counts
language_statistics['Germany'] # for the US
# Out:
# {'C++': 1533,
#  'Java': 2761,
#  'Kotlin': 493,
#  'Python': 2451,
#  'Bash/Shell/PowerShell': 2437,
#  'C#': 1600,
#  'HTML/CSS': 3446,
#  'JavaScript': 3577,
#  'SQL': 2920,
#  'TypeScript': 1299,
#  'WebAssembly': 71,
#  'Clojure': 79,
#  'Go': 539,
#  'R': 313,
#  'PHP': 1603,
#  'C': 1229,
#  'VBA': 365,
#  'Ruby': 410,
#  'Swift': 363,
#  'Other(s):': 680,
#  'Objective-C': 253,
#  'Rust': 295,
#  'Dart': 125,
#  'Assembly': 407,
#  'Erlang': 42,
#  'F#': 55,
#  'Scala': 278,
#  'Elixir': 76}

# %% [markdown]
# Now we have technology usage counts.
# Next, I will calculate the percentage and turn the data into a pandas dataframe for visualization.
#
# The NaNs (missing values) is this calcuation will mean that there are no usage in the specific technoloy. I will fill NaN values with 0.

# %%
# Utility function
# Return a dataframe of relative usage of technologies among the selected countries
def dfWithRelativePreference(statistics, countries):
    """Given the technology usage dictionary, return a dataframe that display
       the relative usage of technologies compared to the entire dataset
       
       Args:
            statistics: statistic object calculated by getStatistics function
            countries: countries to be display and visualized
            
       Returns:
            relative usage percentage dataframe
            
    """
    df = pd.DataFrame(statistics)
    
    df['total_along_row']  = df.sum(axis=1)
    
    df = (df/df.sum()*100).fillna(0) # normalize and fill NaN
    
    df = df[countries+['total_along_row']]
    
    for country in countries:
        df[country] = df[country] - df['total_along_row']
    return df.drop(['total_along_row'], axis=1)

# %% [markdown]
# ### Result

# %%
# Create and display language dataframe with colored bar
df_lang = dfWithRelativePreference(language_statistics,df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, #5fba7d 48.7%, #5fba7d 70.3%, transparent 70.3%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 42.9%, #d65f5f 42.9%, #d65f5f 50.9%, transparent 50.9%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.8%, #d65f5f 12.8%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.5%, #5fba7d 55.5%, #5fba7d 70.3%, transparent 70.3%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.7%, #d65f5f 16.7%, #d65f5f 49.2%, transparent 49.2%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 59.8%, #5fba7d 59.8%, #5fba7d 65.9%, transparent 65.9%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 60.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 62.6%, #5fba7d 62.6%, #5fba7d 94.5%, transparent 94.5%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.6%, #d65f5f 29.6%, #d65f5f 30.6%, transparent 30.6%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.7%, #d65f5f 27.7%, #d65f5f 40.6%, transparent 40.6%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.3%, #d65f5f 35.3%, #d65f5f 36.7%, transparent 36.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.7%, transparent 48.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.4%, #d65f5f 5.4%, #d65f5f 50.9%, transparent 50.9%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.2%, #d65f5f 2.2%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.5%, #5fba7d 55.5%, #5fba7d 99.5%, transparent 99.5%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.2%, #5fba7d 49.2%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.8%, transparent 59.8%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 52.3%, #d65f5f 52.3%, #d65f5f 60.0%, transparent 60.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 62.6%, #5fba7d 62.6%, #5fba7d 89.3%, transparent 89.3%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.6%, #5fba7d 30.6%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.6%, #5fba7d 40.6%, #5fba7d 49.4%, transparent 49.4%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.3%, #d65f5f 13.3%, #d65f5f 36.7%, transparent 36.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, #5fba7d 48.7%, #5fba7d 67.4%, transparent 67.4%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.9%, #5fba7d 50.9%, #5fba7d 51.7%, transparent 51.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.8%, #d65f5f 25.8%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.5%, #5fba7d 55.5%, #5fba7d 63.7%, transparent 63.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.2%, transparent 49.2%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 59.8%, #5fba7d 59.8%, #5fba7d 78.0%, transparent 78.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 21.7%, #d65f5f 21.7%, #d65f5f 60.0%, transparent 60.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 62.6%, #5fba7d 62.6%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.6%, #5fba7d 30.6%, #5fba7d 39.2%, transparent 39.2%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.3%, #d65f5f 22.3%, #d65f5f 40.6%, transparent 40.6%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.7%, #d65f5f 32.7%, #d65f5f 36.7%, transparent 36.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.7%, #d65f5f 44.7%, #d65f5f 48.7%, transparent 48.7%);
#         }    #T_006800f8_8c8d_11ea_b899_00d86118075brow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90de

# %%
# Create and display language dataframe with colored bar
df_lang = dfWithRelativePreference(platform_statistics, df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.8%, #d65f5f 36.8%, #d65f5f 46.3%, transparent 46.3%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.7%, #5fba7d 55.7%, #5fba7d 90.2%, transparent 90.2%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 56.0%, #5fba7d 56.0%, #5fba7d 95.0%, transparent 95.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.7%, #d65f5f 29.7%, #d65f5f 48.5%, transparent 48.5%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.7%, #d65f5f 48.7%, #d65f5f 56.8%, transparent 56.8%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.5%, #5fba7d 35.5%, #5fba7d 43.7%, transparent 43.7%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.9%, #d65f5f 43.9%, #d65f5f 48.5%, transparent 48.5%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, #d65f5f 5.9%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.3%, #d65f5f 27.3%, #d65f5f 48.1%, transparent 48.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.8%, #d65f5f 39.8%, #d65f5f 51.6%, transparent 51.6%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.8%, #d65f5f 49.8%, #d65f5f 64.1%, transparent 64.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.3%, #5fba7d 46.3%, #5fba7d 86.2%, transparent 86.2%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.7%, #d65f5f 17.7%, #d65f5f 55.7%, transparent 55.7%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, #d65f5f 45.6%, #d65f5f 56.0%, transparent 56.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, #5fba7d 48.5%, #5fba7d 69.6%, transparent 69.6%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 56.8%, #5fba7d 56.8%, #5fba7d 79.1%, transparent 79.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.8%, #d65f5f 14.8%, #d65f5f 35.5%, transparent 35.5%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, #5fba7d 48.5%, #5fba7d 91.4%, transparent 91.4%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.9%, #d65f5f 36.9%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.7%, #d65f5f 8.7%, #d65f5f 48.1%, transparent 48.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.6%, #5fba7d 51.6%, #5fba7d 52.5%, transparent 52.5%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.7%, #d65f5f 51.7%, #d65f5f 64.1%, transparent 64.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.3%, #5fba7d 46.3%, #5fba7d 83.2%, transparent 83.2%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.7%, #5fba7d 55.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.2%, #d65f5f 45.2%, #d65f5f 56.0%, transparent 56.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 48.5%, #5fba7d 48.5%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.8%, transparent 56.8%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.5%, #5fba7d 35.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.5%, transparent 48.5%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 29.3%, #d65f5f 29.3%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.1%, transparent 48.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.6%, transparent 51.6%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.1%, transparent 64.1%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.3%, #5fba7d 46.3%, #5fba7d 72.0%, transparent 72.0%);
#         }    #T_00731d1c_8c8d_11ea_9237_00d86118075brow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.7%, #5fba7d 55.7%,

# %%
# Create and display language dataframe with colored bar
df_lang = dfWithRelativePreference(database_statistics, df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.0%, #d65f5f 23.0%, #d65f5f 32.1%, transparent 32.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.1%, #d65f5f 23.1%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 21.4%, #d65f5f 21.4%, #d65f5f 36.4%, transparent 36.4%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, #5fba7d 44.1%, #5fba7d 57.9%, transparent 57.9%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.7%, #5fba7d 46.7%, #5fba7d 65.2%, transparent 65.2%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.6%, #d65f5f 39.6%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.0%, #5fba7d 45.0%, #5fba7d 68.7%, transparent 68.7%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.1%, #d65f5f 32.1%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 57.4%, transparent 57.4%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 56.3%, #d65f5f 56.3%, #d65f5f 64.6%, transparent 64.6%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 28.4%, #d65f5f 28.4%, #d65f5f 35.2%, transparent 35.2%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.9%, #d65f5f 19.9%, #d65f5f 32.1%, transparent 32.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.3%, #d65f5f 33.3%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #d65f5f 7.1%, #d65f5f 36.4%, transparent 36.4%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, #5fba7d 44.1%, #5fba7d 64.9%, transparent 64.9%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.5%, #d65f5f 40.5%, #d65f5f 46.7%, transparent 46.7%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.8%, #d65f5f 14.8%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.5%, #d65f5f 41.5%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.1%, #5fba7d 50.1%, #5fba7d 60.2%, transparent 60.2%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.3%, #5fba7d 53.3%, #5fba7d 65.8%, transparent 65.8%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 64.6%, #5fba7d 64.6%, #5fba7d 73.9%, transparent 73.9%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.1%, #d65f5f 6.1%, #d65f5f 35.2%, transparent 35.2%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.1%, #5fba7d 32.1%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.5%, #5fba7d 45.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.4%, #5fba7d 36.4%, #5fba7d 62.0%, transparent 62.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.3%, #d65f5f 14.3%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.7%, transparent 46.7%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.1%, #5fba7d 44.1%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.8%, #d65f5f 27.8%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.6%, #d65f5f 37.6%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.3%, transparent 53.3%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.6%, transparent 64.6%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 15.8%, #d65f5f 15.8%, #d65f5f 35.2%, transparent 35.2%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.2%, #d65f5f 16.2%, #d65f5f 32.1%, transparent 32.1%);
#         }    #T_007ba1b4_8c8d_11ea_9fd4_00d86118075brow3_col1 {
#             width:  10em;
#              height:  80%;

# %% [markdown]
# ### Conclusion

# %% [markdown]
# *** Insight: The relative popularity of frameworks ***
# - Framework prevalence seems to have correlation with programming languages.
# - A substantial more portion of Singapore developers use Big data tools such as Hadoop and Spark.
# - Developers in China, Japan, and Taiwan seem to focus on AI applications or algorithms based on the Tensorflow usage.

# %% [markdown]
# ## What is the job satisfaction ratio and career satisfaction with different coding languages  in different countries ?

# %% [markdown]
# ### Data Understanding

# %%
df_2019.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist              OpenSourcer                                         OpenSource                              Employment                 Country         Student                                            EdLevel UndergradMajor                                           EduOther OrgSize                                            DevType YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant                          JobSeek          LastHireDate LastInt FizzBuzz                                         JobFactors                                       ResumeUpdate CurrencySymbol CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests PurchaseHow PurchaseWhat               LanguageWorkedWith                           LanguageDesireNextYear DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0           1  I am a student who is learning to code      Yes                    Never  The quality of OSS and closed source software ...  Not employed, and not looking for work          United Kingdom              No                          Primary/elementary school            NaN  Taught yourself a new language, framework, or ...     NaN                                                NaN         4         10          NaN       NaN    NaN      NaN      NaN     NaN                              NaN                   NaN     NaN      NaN                                                NaN                                                NaN            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN  HTML/CSS;Java;JavaScript;Python  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1           2  I am a student who is learning to code       No  Less than once per year  The quality of OSS and closed source software ...      Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time  Secondary school (e.g. American high school, G...            NaN  Taken an online course in programming or softw...     NaN  Developer, desktop or enterprise applications;...       NaN         17          NaN       NaN    NaN      NaN      NaN     NaN  I am actively looking for a job  I've never had a job     NaN      NaN  Financial performance or funding status of the...  Something else changed (education, award, medi...            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN              C++;HTML/CSS;Python                      C++;HTML/CSS;JavaScript;SQL                NaN                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith MiscTechDesireNextYear                  DevEnviron    OpSys               Containers BlockchainOrg                                       BlockchainIs BetterLife                                  ITperson OffOn SocialMedia Extraversion ScreenName SOVisit1st                      SOVisitFreq                                          SOVisitTo        SOFindAnswer                     SOTimeSaved  SOHowMuchTime SOAccount                       SOPartFreq                                             SOJobs                             EntTeams         SOComm                            WelcomeChange                                       SONewContent   Age Gender Trans                Sexuality Ethnicity Dependents           SurveyLength                  SurveyEase
# 0       Django;Flask           Flask;jQuery            Node.js                Node.js  IntelliJ;Notepad++;PyCharm  Windows  I do not use containers           NaN                                                NaN        Yes  Fortunately, someone else has that title   Yes     Twitter       Online   Username       2017  A few times per month or weekly  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  31-60 minutes        No                              NaN  No, I didn't know that Stack Overflow had a jo...  No, and I don't know what those are        Neutral  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  14.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult
# 1             Django                 Django                NaN                    NaN                Atom;PyCharm  Windows  I do not use containers           NaN  Useful across many domains and could change ma...        Yes                                       Yes   Yes   Instagram       Online   Username       2017            Daily or almost daily  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  11-30 minutes       Yes  A few times per month or weekly  No, I knew that Stack Overflow had a job board...  No, and I don't know what those are  Yes, somewhat  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  19.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult

# %% [markdown]
# ### Prepare Data

# %%
df_2019_satisfaction = df_2019[['CareerSat', 'JobSat', 'Employment', 'LanguageWorkedWith' , 'Country']]

# %%
df_2019_satisfaction = df_2019_satisfaction[df_2019_satisfaction.Employment == "Employed full-time"]
df_2019_satisfaction = df_2019_satisfaction.dropna(axis=0)
df_2019_satisfaction['LanguageWorkedWith'] = df_2019_satisfaction['LanguageWorkedWith'].fillna('missing')
df_2019_satisfaction.head()  
df_2019_satisfaction.count()
# Out:
# CareerSat             60706
# JobSat                60706
# Employment            60706
# LanguageWorkedWith    60706
# Country               60706
# dtype: int64

# %%
print(60706/88883)
# Out:
# 0.6829877479383009

# %% [markdown]
# 0.6829877479383009
#
# Interestingly, there are about 60706 responses for 88883 total people. So about 28177 are either not employed full time or did not answer. I think we still have a significant amount to determine an well represented answer. Only about 1/4 of the data is missing and being employed full time means they are serious about coding, are fully committed and act professional. Other factors and distractions could influence happiness, i.e. people not full time can take a break or enjoy other activities.

# %%
df_2019_satisfaction_country = df_2019_satisfaction[df_2019_satisfaction.Country.isin(df_country_list)]

# %%
df_2019_satisfaction_country
# Out:
#                    CareerSat                 JobSat          Employment                                 LanguageWorkedWith        Country
# 3             Very satisfied     Slightly satisfied  Employed full-time                                C;C++;C#;Python;SQL  United States
# 5             Very satisfied     Slightly satisfied  Employed full-time                                         Java;R;SQL         Canada
# 9      Slightly dissatisfied  Slightly dissatisfied  Employed full-time                      C#;Go;JavaScript;Python;R;SQL          India
# 12            Very satisfied         Very satisfied  Employed full-time  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...  United States
# 13            Very satisfied         Very satisfied  Employed full-time                                                C++        Germany
# ...                      ...                    ...                 ...                                                ...            ...
# 88321         Very satisfied         Very satisfied  Employed full-time                               C++;Python;Scala;SQL  United States
# 88323         Very satisfied     Slightly satisfied  Employed full-time  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...  United States
# 88324         Very satisfied         Very satisfied  Employed full-time  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...  United States
# 88325         Very satisfied         Very satisfied  Employed full-time               HTML/CSS;JavaScript;Scala;TypeScript  United States
# 88329  Slightly dissatisfied      Very dissatisfied  Employed full-time             C#;HTML/CSS;Java;JavaScript;PHP;Python    Netherlands
#
# [40651 rows x 5 columns]

# %%
# Count the technology usage in each country, return a nested dictionary 
# in the form: {countyname: {tech1: count1, tech2: count2, ....}, .......}
def getSAtisfactionStatistics(df):
    """ Given the dataframe, counting the technology usage for each country
    
    Args:
        df: dataframe
        tech: Language, Database, Platform, or Framework
    
    Returns:
        A dictionary containing the technology usage for each country
        
    """
    statistics = {}
    JobSat='JobSat'
    for index, row in df[['Country', JobSat]].iterrows():
        # add countries to the list if not exists
        if row['Country'] not in statistics:
            statistics[row['Country']] = {}
        # Technology count
        if row[JobSat] is not np.nan:
            for tar in row[JobSat].split(';'):
                statistics[row['Country']][tar] = statistics[row['Country']].get(tar, 0) + 1 

    return statistics

# %%
Satisfaction_statistics = getSatisfactionStatistics(df_2019_satisfaction_country)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-05adbc1720ec> in <module>
# ----> 1 Satisfaction_statistics = getSatisfactionStatistics(df_2019_satisfaction_country)
#
# <ipython-input-58-e240551a3d54> in getSatisfactionStatistics(df)
#      19             statistics[row['Country']] = {}
#      20         # Technology count
# ---> 21         if row[sat] is not np.nan:
#      22             for tar in row[sat].split(';'):
#      23                 statistics[row['Country']][tar] = sat[row['Country']].get(tar, 0) + 1
#
# NameError: name 'sat' is not defined

# %%
def split_column(df, column):
    ''' Split column by ;,
        returns a splited series.
    '''
    
    df_copy = df
    column_series = df_copy[column].apply(lambda x: x.split(';'))
    
    return column_series

# Splitting the Data Frame by column into a Series. 
#q2['LanguageWorkedWith'] = q2['LanguageWorkedWith'].fillna('missing')
split_list_jobsat = split_column(df_2019_satisfaction, 'JobSat')
split_list_jobsat
# Out:
# 2                        [Slightly satisfied]
# 3                        [Slightly satisfied]
# 4                     [Slightly dissatisfied]
# 5                        [Slightly satisfied]
# 8                        [Slightly satisfied]
#                          ...
# 88325                        [Very satisfied]
# 88326    [Neither satisfied nor dissatisfied]
# 88328    [Neither satisfied nor dissatisfied]
# 88329                     [Very dissatisfied]
# 88330                 [Slightly dissatisfied]
# Name: JobSat, Length: 60706, dtype: object

# %%
# again place data into a array that will then be transformed into a dictionary
def disarray(array_list):
    ''' Flat a nested list,
        returns a flat list.
    '''
    
    objects = []
    
    for row in array_list:
        for obj in row:
            objects.append(obj.strip())
    for elem in df_2019_satisfaction['JobSat']:
        objects.append(elem)
    return objects

# Flatting nested list objects.
list_worked_languages = disarray(split_list_jobsat)
# list_worked_languages

# %%
def group_list(data_list):
    ''' Group by count to a list,
        returns a result dict only for JobSat.
    '''
    
    grouped_list = dict(Counter(data_list))
    grouped_dict = [{'JobSat':key, 'Count': value} for key, value in grouped_list.items()]
    
    return grouped_dict

    
# Groping a list and creating a dict.
dict_worked_languages = group_list(list_worked_languages)
dict_worked_languages
# Out:
# [{'JobSat': 'Slightly satisfied', 'Count': 41902},
#  {'JobSat': 'Slightly dissatisfied', 'Count': 18664},
#  {'JobSat': 'Very satisfied', 'Count': 38286},
#  {'JobSat': 'Neither satisfied nor dissatisfied', 'Count': 14296},
#  {'JobSat': 'Very dissatisfied', 'Count': 8264}]

# %%
def create_dataframe(data_dicts): #column1, column2):
    ''' Input a dictionary list
        returns a pandas dataframe
    '''
    
    
    df1 = pd.DataFrame.from_dict(data_dicts)


    
    return df1

# Creating a Data Frame appending the data.
worked_jobsat = create_dataframe(dict_worked_languages)
worked_jobsat
# Out:
#                                JobSat  Count
# 0                  Slightly satisfied  41902
# 1               Slightly dissatisfied  18664
# 2                      Very satisfied  38286
# 3  Neither satisfied nor dissatisfied  14296
# 4                   Very dissatisfied   8264

# %%
# Get the top 5 job Satisfaction Categies Counted
top_5_job_sat = worked_jobsat.sort_values(by=['Count'], ascending=False).head(10)['JobSat'].unique()


jobsat_chart = worked_jobsat[worked_jobsat['JobSat'].isin(top_5_job_sat)]
jobsat_chart
# Out:
#                                JobSat  Count
# 0                  Slightly satisfied  41902
# 1               Slightly dissatisfied  18664
# 2                      Very satisfied  38286
# 3  Neither satisfied nor dissatisfied  14296
# 4                   Very dissatisfied   8264

# %% [markdown]
#  ### Data Modeling

# %%
# Figure 3 — Number of Job Satisfaction Category Totals 
plt.figure(figsize=(14,8))
sns.barplot(x = 'Count', 
            y = 'JobSat',
            data = jobsat_chart.sort_values(by='Count'))
plt.xlabel("Count", fontsize = 14)
plt.ylabel("Job Satisfation Type", fontsize = 14)
plt.legend(fontsize='x-large', title_fontsize='40')
plt.title('Number of Job Satisfaction Category Totals', size = 16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Get the top 5 job Satisfaction Categies Counted
top_5_job_sat = worked_jobsat.sort_values(by=['Count'], ascending=False).head(10)['JobSat'].unique()

jobsat_chart = worked_jobsat[worked_jobsat['JobSat'].isin(top_5_job_sat)]
jobsat_chart
# Out:
#                                JobSat  Count
# 0                  Slightly satisfied  41902
# 1               Slightly dissatisfied  18664
# 2                      Very satisfied  38286
# 3  Neither satisfied nor dissatisfied  14296
# 4                   Very dissatisfied   8264

# %%
### What is the job satisfaction with language (the code that is most in demand)?

# %% [markdown]
# ## What's the pay for developers like?

# %%
df_2019_salaries = df_2019[['DevType', 'Country','ConvertedComp']]

for column in df_2019_salaries.columns.tolist():
    col_desc = df_2019_schema[df_2019_schema['Column']==column]['QuestionText'].iloc[0]
    print(col_desc)
# Out:
# Which of the following describe you? Please select all that apply.
# In which country do you currently reside?
# Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.

# %% [markdown]
# ### Schema Questions
# - Which of the following describe you? Please select all that apply.
# - In which country do you currently reside?
# - Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.

# %%
# Lets check for missing values in salaries_df
df_2019_salaries.isnull().sum()
# Out:
# DevType           7548
# Country            132
# ConvertedComp    33060
# dtype: int64

# %%
# salaries_df missing values in %
round((df_2019_salaries.isnull().sum()/df_2019_salaries.shape[0])*100,1)
# Out:
# DevType           8.5
# Country           0.1
# ConvertedComp    37.2
# dtype: float64

# %% [markdown]
# Insight
#
# it seems that a large number of developers do not reveal their salaries, and this could be due to privacy concerns.
#
# To assess the pay for developers, we will make use of salaries distribution by country. This allows us to compare like with like.

# %%
# drop rows with missing values from salaries df
df_2019_salaries_clean = df_2019_salaries.dropna().reset_index()
df_2019_salaries_clean.head()
# Out:
#    index                                            DevType        Country  ConvertedComp
# 0      2  Designer;Developer, back-end;Developer, front-...       Thailand         8820.0
# 1      3                              Developer, full-stack  United States        61000.0
# 2      5  Data or business analyst;Data scientist or mac...         Canada       366420.0
# 3      8  Database administrator;Developer, back-end;Dev...    New Zealand        95179.0
# 4      9  Data or business analyst;Data scientist or mac...          India        13293.0

# %%
df_2019_salaries_clean.Country.value_counts().reset_index()
# Out:
#                                          index  Country
# 0                                United States    14756
# 1                               United Kingdom     3967
# 2                                        India     3953
# 3                                      Germany     3734
# 4                                       Canada     2225
# 5                                       France     1619
# 6                                       Brazil     1395
# 7                                       Poland     1307
# 8                                    Australia     1233
# 9                                        Spain     1189
# 10                                 Netherlands     1184
# 11                          Russian Federation     1095
# 12                                       Italy      932
# 13                                      Sweden      901
# 14                                 Switzerland      663
# 15                                      Israel      569
# 16                                     Ukraine      535
# 17                                     Austria      500
# 18                                      Turkey      496
# 19                              Czech Republic      477
# 20                                      Mexico      457
# 21                                     Belgium      456
# 22                                    Pakistan      421
# 23                                      Norway      415
# 24                                        Iran      415
# 25                                South Africa      414
# 26                                     Denmark      413
# 27                                     Romania      409
# 28                                    Bulgaria      401
# 29                                   Argentina      389
# 30                                     Finland      380
# 31                                 New Zealand      354
# 32                                    Portugal      353
# 33                                     Ireland      336
# 34                                     Hungary      324
# 35                                      Greece      304
# 36                                       Japan      253
# 37                                  Bangladesh      248
# 38                                       China      240
# 39                                      Serbia      218
# 40                                    Colombia      209
# 41                                   Indonesia      205
# 42                                    Slovenia      204
# 43                                     Nigeria      196
# 44                                     Croatia      167
# 45                                   Sri Lanka      163
# 46                                   Lithuania      160
# 47                                   Singapore      153
# 48                                 Philippines      149
# 49                                       Egypt      148
# 50                                    Slovakia      145
# 51                                       Chile      143
# 52                                     Estonia      141
# 53                                    Malaysia      136
# 54                                     Belarus      123
# 55                          Hong Kong (S.A.R.)      107
# 56                                      Taiwan      106
# 57                                    Thailand      102
# 58                                       Kenya       99
# 59                                      Latvia       98
# 60                                     Uruguay       91
# 61                        United Arab Emirates       87
# 62                                    Viet Nam       85
# 63                                       Nepal       83
# 64                                        Peru       80
# 65                                 South Korea       70
# 66                                     Lebanon       67
# 67                          Dominican Republic       67
# 68            Other Country (Not Listed Above)       59
# 69                      Bosnia and Herzegovina       59
# 70                                     Ecuador       56
# 71                                     Tunisia       52
# 72                                  Costa Rica       51
# 73                                     Albania       50
# 74                                     Georgia       49
# 75                                Saudi Arabia       48
# 76                                 El Salvador       46
# 77                                     Armenia       45
# 78        Venezuela, Bolivarian Republic of...       43
# 79                                  Luxembourg       43
# 80                                       Malta       43
# 81                                   Guatemala       42
# 82                                    Paraguay       41
# 83                                     Algeria       40
# 84                                     Morocco       39
# 85                                  Kazakhstan       38
# 86                                      Cyprus       37
# 87                                      Uganda       34
# 88                                      Jordan       34
# 89                         Republic of Moldova       31
# 90                                       Ghana       31
# 91   The former Yugoslav Republic of Macedonia       30
# 92                                     Iceland       27
# 93                                    Ethiopia       24
# 94                                  Azerbaijan       24
# 95                                     Bolivia       24
# 96                                    Cameroon       23
# 97                                      Panama       22
# 98                                   Nicaragua       22
# 99                                        Cuba       18
# 100                United Republic of Tanzania       17
# 101                          Republic of Korea       16
# 102                                    Myanmar       16
# 103                                   Honduras       15
# 104                                  Mauritius       15
# 105                                   Zimbabwe       15
# 106                                 Uzbekistan       14
# 107                              Côte d'Ivoire       13
# 108                                      Sudan       12
# 109                                 Kyrgyzstan       12
# 110                                    Jamaica       11
# 111                                    Bahrain       10
# 112                                       Iraq       10
# 113                                    Senegal       10
# 114                                   Mongolia       10
# 115                                 Montenegro        9
# 116                                Afghanistan        9
# 117                        Trinidad and Tobago        9
# 118                       Syrian Arab Republic        8
# 119                                     Zambia        8
# 120                                   Cambodia        8
# 121                                     Kuwait        8
# 122                                      Qatar        6
# 123                                      Yemen        6
# 124                                 Madagascar        6
# 125                                   Maldives        6
# 126                                     Rwanda        5
# 127                                 Mozambique        4
# 128                                    Somalia        4
# 129                     Libyan Arab Jamahiriya        4
# 130                                  Swaziland        4
# 131                               Turkmenistan        3
# 132                                   Botswana        3
# 133                  Congo, Republic of the...        3
# 134                                      Haiti        2
# 135                                    Burundi        2
# 136                                     Monaco        2
# 137                                       Fiji        2
# 138                                 Tajikistan        2
# 139                                    Andorra        2
# 140                                 San Marino        2
# 141                                   Barbados        1
# 142                          Brunei Darussalam        1
# 143                                    Lesotho        1
# 144                                Timor-Leste        1
# 145      Democratic People's Republic of Korea        1
# 146                                     Malawi        1
# 147                                       Mali        1
# 148                                     Angola        1
# 149                              Liechtenstein        1
# 150                                     Guinea        1
# 151           Lao People's Democratic Republic        1
# 152                                       Oman        1
# 153                                 Seychelles        1
# 154           Saint Vincent and the Grenadines        1
# 155                                       Togo        1
# 156                                       Chad        1
# 157                                   Djibouti        1
# 158                               Burkina Faso        1
# 159           Democratic Republic of the Congo        1

# %%
# now lets plot salary distributions for the top 20 countries

fig = plt.figure(figsize=(20,10))

countries = df_2019_salaries_clean['Country'].value_counts().sort_values(ascending=False)[:9].index.tolist()

for i,country in enumerate(countries):
    plt.subplot(3,3,i+1)
    temp_salaries = df_2019_salaries_clean.loc[df_2019_salaries_clean['Country']==country,'ConvertedComp']

    ax = temp_salaries.plot(kind='kde')
    ax.axvline(temp_salaries.mean(), linestyle = '-', color = 'black')
    ax.text((temp_salaries.mean() + 1500), (float(ax.get_ylim()[1])*0.55), 'mean = $ ' + str(round(temp_salaries.mean(),0)), fontsize = 12)
    ax.set_xlabel('Annual Salary in USD')
    ax.set_xlim(-temp_salaries.mean(),temp_salaries.mean()+2*temp_salaries.std())
    
    ax.set_title('Annual Salary Distribution in {}'.format(country))

plt.tight_layout()
plt.savefig('developer_salaries_by_country.png',bbox_inches = 'tight')
plt.show()
