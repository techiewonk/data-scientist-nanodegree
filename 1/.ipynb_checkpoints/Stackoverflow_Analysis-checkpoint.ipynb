# %% [markdown]
# # Stackoverflow survey data

# %% [markdown]
# ## Data Analysis Process
# 1. Business Understanding to define Problem statement.
# 1.  Data Understanding.
# 2.  Prepare Data.
# 3.  Data Modeling.
# 4.  Evaluate the Results
# 5.  Deploy.

# %% [markdown]
# ## Business Understanding to define Problem statement.

# %% [markdown]
# ***I want to set up a software development businesses worldwide and hire developers from the respective countries. in that process, I want to learn about technologies used by developers in software development. which country and tools I have to target based on the satisfaction level of developer and lastly How much I have to pay for a respective developer from respective countries ***

# %% [markdown]
# ## Problem Statement Includes
# - Which are the Most popular software development scenarios used by developers in year 2019 in different countries  ?
# - Job satisfaction ratio and career satisfaction with different coding languages in different countries ?
# - What should be My Appropriate budget to pay for developers ?

# %% [markdown]
# # Dataset and Data Understanding Solution Progress

# %% [markdown]
# ## Header for import

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import re
import collections
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['figure.dpi'] = 100
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'bbox_inches':None}
from plotnine import *
from feature_selector import FeatureSelector

# %% [markdown]
# ## Data import from Developer Survey

# %%
df_2019 = pd.read_csv(r'.\data\developer_survey_2019\survey_results_public.csv')

# %%
df_2018 = pd.read_csv(r'.\data\developer_survey_2018\survey_results_public.csv',low_memory=False)

# %%
df_2017 = pd.read_csv(r'.\data\developer_survey_2017\survey_results_public.csv',low_memory=False)

# %%
df_2019_schema  = pd.read_csv(r'.\data\developer_survey_2019\survey_results_schema.csv')

# %%
df_2018_schema  = pd.read_csv(r'.\data\developer_survey_2018\survey_results_schema.csv')

# %%
df_2017_schema  = pd.read_csv(r'.\data\developer_survey_2017\survey_results_schema.csv')

# %% [markdown]
# ## Data Understanding and Presentation

# %%
df_2019.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist              OpenSourcer                                         OpenSource                              Employment                 Country         Student                                            EdLevel UndergradMajor                                           EduOther OrgSize                                            DevType YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant                          JobSeek          LastHireDate LastInt FizzBuzz                                         JobFactors                                       ResumeUpdate CurrencySymbol CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests PurchaseHow PurchaseWhat               LanguageWorkedWith                           LanguageDesireNextYear DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0           1  I am a student who is learning to code      Yes                    Never  The quality of OSS and closed source software ...  Not employed, and not looking for work          United Kingdom              No                          Primary/elementary school            NaN  Taught yourself a new language, framework, or ...     NaN                                                NaN         4         10          NaN       NaN    NaN      NaN      NaN     NaN                              NaN                   NaN     NaN      NaN                                                NaN                                                NaN            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN  HTML/CSS;Java;JavaScript;Python  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1           2  I am a student who is learning to code       No  Less than once per year  The quality of OSS and closed source software ...      Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time  Secondary school (e.g. American high school, G...            NaN  Taken an online course in programming or softw...     NaN  Developer, desktop or enterprise applications;...       NaN         17          NaN       NaN    NaN      NaN      NaN     NaN  I am actively looking for a job  I've never had a job     NaN      NaN  Financial performance or funding status of the...  Something else changed (education, award, medi...            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN              C++;HTML/CSS;Python                      C++;HTML/CSS;JavaScript;SQL                NaN                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith MiscTechDesireNextYear                  DevEnviron    OpSys               Containers BlockchainOrg                                       BlockchainIs BetterLife                                  ITperson OffOn SocialMedia Extraversion ScreenName SOVisit1st                      SOVisitFreq                                          SOVisitTo        SOFindAnswer                     SOTimeSaved  SOHowMuchTime SOAccount                       SOPartFreq                                             SOJobs                             EntTeams         SOComm                            WelcomeChange                                       SONewContent   Age Gender Trans                Sexuality Ethnicity Dependents           SurveyLength                  SurveyEase
# 0       Django;Flask           Flask;jQuery            Node.js                Node.js  IntelliJ;Notepad++;PyCharm  Windows  I do not use containers           NaN                                                NaN        Yes  Fortunately, someone else has that title   Yes     Twitter       Online   Username       2017  A few times per month or weekly  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  31-60 minutes        No                              NaN  No, I didn't know that Stack Overflow had a jo...  No, and I don't know what those are        Neutral  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  14.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult
# 1             Django                 Django                NaN                    NaN                Atom;PyCharm  Windows  I do not use containers           NaN  Useful across many domains and could change ma...        Yes                                       Yes   Yes   Instagram       Online   Username       2017            Daily or almost daily  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  11-30 minutes       Yes  A few times per month or weekly  No, I knew that Stack Overflow had a job board...  No, and I don't know what those are  Yes, somewhat  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  19.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult

# %%
# df_2018.head(2)

# %%
# df_2017.head(2)

# %%
for col in df_2019.columns:
    print(col)
# Out:
# Respondent
# MainBranch
# Hobbyist
# OpenSourcer
# OpenSource
# Employment
# Country
# Student
# EdLevel
# UndergradMajor
# EduOther
# OrgSize
# DevType
# YearsCode
# Age1stCode
# YearsCodePro
# CareerSat
# JobSat
# MgrIdiot
# MgrMoney
# MgrWant
# JobSeek
# LastHireDate
# LastInt
# FizzBuzz
# JobFactors
# ResumeUpdate
# CurrencySymbol
# CurrencyDesc
# CompTotal
# CompFreq
# ConvertedComp
# WorkWeekHrs
# WorkPlan
# WorkChallenge
# WorkRemote
# WorkLoc
# ImpSyn
# CodeRev
# CodeRevHrs
# UnitTests
# PurchaseHow
# PurchaseWhat
# LanguageWorkedWith
# LanguageDesireNextYear
# DatabaseWorkedWith
# DatabaseDesireNextYear
# PlatformWorkedWith
# PlatformDesireNextYear
# WebFrameWorkedWith
# WebFrameDesireNextYear
# MiscTechWorkedWith
# MiscTechDesireNextYear
# DevEnviron
# OpSys
# Containers
# BlockchainOrg
# BlockchainIs
# BetterLife
# ITperson
# OffOn
# SocialMedia
# Extraversion
# ScreenName
# SOVisit1st
# SOVisitFreq
# SOVisitTo
# SOFindAnswer
# SOTimeSaved
# SOHowMuchTime
# SOAccount
# SOPartFreq
# SOJobs
# EntTeams
# SOComm
# WelcomeChange
# SONewContent
# Age
# Gender
# Trans
# Sexuality
# Ethnicity
# Dependents
# SurveyLength
# SurveyEase

# %%
# for col in df_2017.columns:
#     print(col)

# %% [markdown]
# ## Selecting last year for analysis

# %%
df_country_count = df_2019.groupby(['Country'])['Respondent'].count().sort_values(ascending=False)
# df_country_count

# %% [markdown]
# # Most popular software development scenarios used by developers in year 2019 in different countries ?

# %% [markdown]
# ## Selecting my favorable Counties

# %%
df_country_list = [
'United Kingdom', 'United States', 'Canada', 'India', 'Germany', 'Australia', 'Russian Federation', 'Brazil', 'Spain', 'France', 'Netherlands'
]

# %% [markdown]
# ## Selecting target attributes used for analysis

# %%
# Attributes list
target_attributes = [
    # Background
    'Country',
    'YearsCode',
    'DevType',
    'YearsCodePro',
    'CareerSat',
    'Gender',
    # Technologies
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'DatabaseWorkedWith',
    'DatabaseDesireNextYear',
    'PlatformWorkedWith',
    'PlatformDesireNextYear',
    'OpSys',
    'Sexuality',
    'DevType'
]

# %% [markdown]
# ## Prepare Data - filter by countries

# %%
df_2019_top = df_2019[df_2019.Country.isin(df_country_list)] # filter by countries
# df_2019_top

# %% [markdown]
# ## Prepare Data -  filter by attributes

# %%
df_2019_top_filterd = df_2019_top[target_attributes] # filter by attributes
df_2019_top_filterd.head()
# Out:
#           Country YearsCode                                            DevType      YearsCodePro              CareerSat Gender                                 LanguageWorkedWith                             LanguageDesireNextYear                                 DatabaseWorkedWith                             DatabaseDesireNextYear                           PlatformWorkedWith                             PlatformDesireNextYear        OpSys                Sexuality                                            DevType
# 0  United Kingdom         4                                                NaN               NaN                    NaN    Man                    HTML/CSS;Java;JavaScript;Python    C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL                                             SQLite                                              MySQL                                MacOS;Windows                            Android;Arduino;Windows      Windows  Straight / Heterosexual                                                NaN
# 3   United States         3                              Developer, full-stack  Less than 1 year         Very satisfied    Man                                C;C++;C#;Python;SQL                                C;C#;JavaScript;SQL                                       MySQL;SQLite                                       MySQL;SQLite                                Linux;Windows                                      Linux;Windows      Windows  Straight / Heterosexual                              Developer, full-stack
# 5          Canada        13  Data or business analyst;Data scientist or mac...                 3         Very satisfied    Man                                         Java;R;SQL                                   Python;Scala;SQL                                 MongoDB;PostgreSQL                                         PostgreSQL  Android;Google Cloud Platform;Linux;Windows        Android;Google Cloud Platform;Linux;Windows      Windows  Straight / Heterosexual  Data or business analyst;Data scientist or mac...
# 7           India         8     Developer, back-end;Engineer, site reliability               NaN                    NaN    Man  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...  Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...  Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...  Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...          AWS;Docker;Heroku;Linux;MacOS;Slack  Android;Arduino;AWS;Docker;Google Cloud Platfo...  Linux-based  Straight / Heterosexual     Developer, back-end;Engineer, site reliability
# 9           India        12  Data or business analyst;Data scientist or mac...                10  Slightly dissatisfied    NaN                      C#;Go;JavaScript;Python;R;SQL               C#;Go;JavaScript;Kotlin;Python;R;SQL  Elasticsearch;MongoDB;Microsoft SQL Server;MyS...         Elasticsearch;MongoDB;Microsoft SQL Server                                Linux;Windows                 Android;Linux;Raspberry Pi;Windows      Windows                      NaN  Data or business analyst;Data scientist or mac...

# %%
df_2019_top_filterd[['LanguageWorkedWith', 'DatabaseWorkedWith', 'PlatformWorkedWith' ]].sample(10)
# Out:
#                                       LanguageWorkedWith                                 DatabaseWorkedWith                                 PlatformWorkedWith
# 39293                                C;C++;C#;Java;Swift                         Microsoft SQL Server;MySQL                                Linux;MacOS;Windows
# 7564                                 C++;Java;Python;SQL                                         PostgreSQL                               Docker;Linux;Windows
# 8775   Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...                                  Oracle;PostgreSQL  Arduino;AWS;Docker;Linux;MacOS;Raspberry Pi;Sl...
# 65981                                    Java;Kotlin;SQL                         Microsoft SQL Server;MySQL                           AWS;Docker;Linux;Windows
# 57024  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...                              Couchbase;MySQL;Redis               AWS;Linux;MacOS;Raspberry Pi;Windows
# 6462   Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...                       MariaDB;MongoDB;MySQL;SQLite                                   AWS;Heroku;Linux
# 75700              C#;HTML/CSS;JavaScript;SQL;TypeScript  DynamoDB;MongoDB;Microsoft SQL Server;MySQL;SQ...                                AWS;Microsoft Azure
# 13634  Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...                         Microsoft SQL Server;MySQL                                      Linux;Windows
# 1821   Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...  MariaDB;Microsoft SQL Server;MySQL;Oracle;Post...  AWS;Docker;Heroku;Linux;Microsoft Azure;Raspbe...
# 72320                                     JavaScript;VBA                                                NaN                              Google Cloud Platform

# %%
df_2019_top_filterd[['LanguageWorkedWith', 'DatabaseWorkedWith', 'PlatformWorkedWith']].isnull().mean()
# Out:
# LanguageWorkedWith    0.010727
# DatabaseWorkedWith    0.148457
# PlatformWorkedWith    0.091454
# dtype: float64

# %%
# Count the technology usage in each country, return a nested dictionary 
# in the form: {countyname: {tech1: count1, tech2: count2, ....}, .......}
def getStatistics(df, tech):
    """ Given the dataframe, counting the technology usage for each country
    
    Args:
        df: dataframe
        tech: Language, Database, Platform, or Framework
    
    Returns:
        A dictionary containing the technology usage for each country
        
    """
    statistics = {}
    WorkedWith = tech + 'WorkedWith'
    for index, row in df[['Country', WorkedWith]].iterrows():
        # add countries to the list if not exists
        if row['Country'] not in statistics:
            statistics[row['Country']] = {}
        # Technology count
        if row[WorkedWith] is not np.nan:
            for tar in row[WorkedWith].split(';'):
                statistics[row['Country']][tar] = statistics[row['Country']].get(tar, 0) + 1 

    return statistics

# %%
# Counting the tech usage
language_statistics = getStatistics(df_2019_top_filterd, 'Language')
platform_statistics = getStatistics(df_2019_top_filterd, 'Platform')
database_statistics = getStatistics(df_2019_top_filterd, 'Database')

# %%
# keys: the countries 
language_statistics.keys()
# Out:
# dict_keys(['United Kingdom', 'United States', 'Canada', 'India', 'Germany', 'Australia', 'Russian Federation', 'Brazil', 'Spain', 'France', 'Netherlands'])

# %%
# values: the technology counts
language_statistics['Germany'] # for the US
# Out:
# {'C++': 1533,
#  'Java': 2761,
#  'Kotlin': 493,
#  'Python': 2451,
#  'Bash/Shell/PowerShell': 2437,
#  'C#': 1600,
#  'HTML/CSS': 3446,
#  'JavaScript': 3577,
#  'SQL': 2920,
#  'TypeScript': 1299,
#  'WebAssembly': 71,
#  'Clojure': 79,
#  'Go': 539,
#  'R': 313,
#  'PHP': 1603,
#  'C': 1229,
#  'VBA': 365,
#  'Ruby': 410,
#  'Swift': 363,
#  'Other(s):': 680,
#  'Objective-C': 253,
#  'Rust': 295,
#  'Dart': 125,
#  'Assembly': 407,
#  'Erlang': 42,
#  'F#': 55,
#  'Scala': 278,
#  'Elixir': 76}

# %% [markdown]
# Now we have technology usage counts.
# Next, I will calculate the percentage and turn the data into a pandas dataframe for visualization.
#
# The NaNs (missing values) is this calcuation will mean that there are no usage in the specific technoloy. I will fill NaN values with 0.

# %%
# Utility function
# Return a dataframe of relative usage of technologies among the selected countries
def dfWithRelativePreference(statistics, countries):
    """Given the technology usage dictionary, return a dataframe that display
       the relative usage of technologies compared to the entire dataset
       
       Args:
            statistics: statistic object calculated by getStatistics function
            countries: countries to be display and visualized
            
       Returns:
            relative usage percentage dataframe
            
    """
    df = pd.DataFrame(statistics)
    
    df['total_along_row']  = df.sum(axis=1)
    
    df = (df/df.sum()*100).fillna(0) # normalize and fill NaN
    
    df = df[countries+['total_along_row']]
    
    for country in countries:
        df[country] = df[country] - df['total_along_row']
    return df.drop(['total_along_row'], axis=1)

# %% [markdown]
# ##  Result

# %% [markdown]
# ## Create and display language dataframe with colored bar

# %%
df_lang = dfWithRelativePreference(language_statistics,df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 41.5%, #d65f5f 41.5%, #d65f5f 48.7%, transparent 48.7%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.8%, #d65f5f 48.8%, #d65f5f 50.9%, transparent 50.9%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 53.6%, transparent 53.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 55.5%, #5fba7d 55.5%, #5fba7d 57.6%, transparent 57.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 49.2%, #5fba7d 49.2%, #5fba7d 55.0%, transparent 55.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.2%, #d65f5f 51.2%, #d65f5f 59.8%, transparent 59.8%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.0%, #5fba7d 60.0%, #5fba7d 67.6%, transparent 67.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.7%, #d65f5f 59.7%, #d65f5f 62.6%, transparent 62.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.6%, #5fba7d 30.6%, #5fba7d 35.5%, transparent 35.5%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.6%, #5fba7d 40.6%, #5fba7d 49.8%, transparent 49.8%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 28.4%, #d65f5f 28.4%, #d65f5f 36.7%, transparent 36.7%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.7%, #5fba7d 48.7%, #5fba7d 75.9%, transparent 75.9%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50.9%, #5fba7d 50.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 55.5%, transparent 55.5%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 49.2%, #5fba7d 49.2%, #5fba7d 65.4%, transparent 65.4%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.8%, #5fba7d 59.8%, #5fba7d 83.0%, transparent 83.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.0%, #5fba7d 60.0%, #5fba7d 78.0%, transparent 78.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 62.6%, transparent 62.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.3%, #d65f5f 0.3%, #d65f5f 30.6%, transparent 30.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.6%, #5fba7d 40.6%, #5fba7d 42.9%, transparent 42.9%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 36.7%, #5fba7d 36.7%, #5fba7d 42.5%, transparent 42.5%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.9%, #d65f5f 10.9%, #d65f5f 48.7%, transparent 48.7%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.9%, #d65f5f 17.9%, #d65f5f 50.9%, transparent 50.9%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.0%, #d65f5f 31.0%, #d65f5f 45.5%, transparent 45.5%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 55.5%, #5fba7d 55.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 49.2%, #5fba7d 49.2%, #5fba7d 51.7%, transparent 51.7%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 38.8%, #d65f5f 38.8%, #d65f5f 59.8%, transparent 59.8%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.0%, #5fba7d 60.0%, #5fba7d 63.5%, transparent 63.5%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 55.5%, #d65f5f 55.5%, #d65f5f 62.6%, transparent 62.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.9%, #d65f5f 21.9%, #d65f5f 30.6%, transparent 30.6%);
#         }    #T_0dbc7cc0_8d6f_11ea_8618_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.6%, #5fba7d 40.6%, #5fba7d 75.5%, t

# %% [markdown]
# ## Create and display platform dataframe with colored bar

# %%
df_lang = dfWithRelativePreference(platform_statistics, df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.3%, #5fba7d 46.3%, #5fba7d 83.2%, transparent 83.2%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 55.7%, #5fba7d 55.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.2%, #d65f5f 45.2%, #d65f5f 56.0%, transparent 56.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.5%, #5fba7d 48.5%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 56.8%, transparent 56.8%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.5%, #5fba7d 35.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 48.5%, transparent 48.5%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 29.3%, #d65f5f 29.3%, #d65f5f 51.3%, transparent 51.3%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 48.1%, transparent 48.1%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 51.6%, transparent 51.6%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 64.1%, transparent 64.1%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 46.3%, transparent 46.3%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 55.7%, transparent 55.7%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 14.4%, #d65f5f 14.4%, #d65f5f 56.0%, transparent 56.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.5%, #5fba7d 48.5%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 56.8%, #5fba7d 56.8%, #5fba7d 64.5%, transparent 64.5%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 35.5%, transparent 35.5%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.5%, #5fba7d 48.5%, #5fba7d 63.6%, transparent 63.6%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #5fba7d 51.3%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.1%, #5fba7d 48.1%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.6%, #5fba7d 51.6%, #5fba7d 63.4%, transparent 63.4%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 64.1%, #5fba7d 64.1%, #5fba7d 76.1%, transparent 76.1%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 14.6%, #d65f5f 14.6%, #d65f5f 46.3%, transparent 46.3%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.8%, #d65f5f 48.8%, #d65f5f 55.7%, transparent 55.7%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 54.4%, #d65f5f 54.4%, #d65f5f 56.0%, transparent 56.0%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.5%, #5fba7d 48.5%, #5fba7d 50.7%, transparent 50.7%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 56.8%, #5fba7d 56.8%, #5fba7d 68.1%, transparent 68.1%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.5%, #5fba7d 35.5%, #5fba7d 37.3%, transparent 37.3%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.7%, #d65f5f 43.7%, #d65f5f 48.5%, transparent 48.5%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #5fba7d 51.3%, #5fba7d 66.6%, transparent 66.6%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.1%, #5fba7d 48.1%, #5fba7d 56.8%, transparent 56.8%);
#         }    #T_0dcb66a8_8d6f_11ea_a1e3_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.6%, #5fba7d 51.6%, #5fba7d 60.0%, tra

# %% [markdown]
# ## Create and display database dataframe with colored bar

# %%
df_lang = dfWithRelativePreference(database_statistics, df_country_list)
df_lang.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 26.1%, #d65f5f 26.1%, #d65f5f 32.1%, transparent 32.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 50.4%, transparent 50.4%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.8%, #d65f5f 31.8%, #d65f5f 36.4%, transparent 36.4%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.1%, #5fba7d 44.1%, #5fba7d 44.2%, transparent 44.2%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.0%, #d65f5f 44.0%, #d65f5f 46.7%, transparent 46.7%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.8%, #d65f5f 35.8%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.0%, #5fba7d 45.0%, #5fba7d 45.9%, transparent 45.9%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 41.0%, #d65f5f 41.0%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.3%, #5fba7d 53.3%, #5fba7d 53.6%, transparent 53.6%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 64.6%, #5fba7d 64.6%, #5fba7d 66.9%, transparent 66.9%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.2%, #5fba7d 35.2%, #5fba7d 40.7%, transparent 40.7%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.1%, #5fba7d 32.1%, #5fba7d 36.4%, transparent 36.4%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 46.3%, transparent 46.3%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.2%, #d65f5f 30.2%, #d65f5f 36.4%, transparent 36.4%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.7%, #d65f5f 43.7%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.6%, #d65f5f 46.6%, #d65f5f 46.7%, transparent 46.7%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.1%, #5fba7d 44.1%, #5fba7d 46.0%, transparent 46.0%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 42.6%, #d65f5f 42.6%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 41.3%, #d65f5f 41.3%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.3%, #5fba7d 53.3%, #5fba7d 53.8%, transparent 53.8%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 64.6%, #5fba7d 64.6%, #5fba7d 66.3%, transparent 66.3%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.1%, #d65f5f 31.1%, #d65f5f 35.2%, transparent 35.2%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.1%, #5fba7d 32.1%, #5fba7d 51.2%, transparent 51.2%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 69.6%, transparent 69.6%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.1%, #d65f5f 30.1%, #d65f5f 36.4%, transparent 36.4%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 34.7%, #d65f5f 34.7%, #d65f5f 44.1%, transparent 44.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.8%, #d65f5f 30.8%, #d65f5f 46.7%, transparent 46.7%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.1%, #5fba7d 44.1%, #5fba7d 69.3%, transparent 69.3%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 26.4%, #d65f5f 26.4%, #d65f5f 45.0%, transparent 45.0%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.7%, #d65f5f 37.7%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.2%, #d65f5f 43.2%, #d65f5f 53.3%, transparent 53.3%);
#         }    #T_0dd71e76_8d6f_11ea_aeea_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.0%, #d65f5f 44.0%, #d65f5f 64.6%, t

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *** Insight: The relative popularity of frameworks ***
# - Framework prevalence seems to have a correlation with programming languages and that too different in different countries. but C, JAVA, PHP are still the most commonly used languages, Python and javascript uses are increasing exponentially.
# - A substantial more portion of Germany developers use several Operating system tools such as Linux , Docker.
# - in Database Platforms MYSQL, Fierbase, Oracle, MongoDB , DynamoDB are more famous in several countries

# %% [markdown]
# # What is the job satisfaction ratio and career satisfaction with different coding languages  in different countries ?

# %%
df_2019.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist              OpenSourcer                                         OpenSource                              Employment                 Country         Student                                            EdLevel UndergradMajor                                           EduOther OrgSize                                            DevType YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney MgrWant                          JobSeek          LastHireDate LastInt FizzBuzz                                         JobFactors                                       ResumeUpdate CurrencySymbol CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs WorkPlan WorkChallenge WorkRemote WorkLoc ImpSyn CodeRev  CodeRevHrs UnitTests PurchaseHow PurchaseWhat               LanguageWorkedWith                           LanguageDesireNextYear DatabaseWorkedWith DatabaseDesireNextYear PlatformWorkedWith   PlatformDesireNextYear  \
# 0           1  I am a student who is learning to code      Yes                    Never  The quality of OSS and closed source software ...  Not employed, and not looking for work          United Kingdom              No                          Primary/elementary school            NaN  Taught yourself a new language, framework, or ...     NaN                                                NaN         4         10          NaN       NaN    NaN      NaN      NaN     NaN                              NaN                   NaN     NaN      NaN                                                NaN                                                NaN            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN  HTML/CSS;Java;JavaScript;Python  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL             SQLite                  MySQL      MacOS;Windows  Android;Arduino;Windows
# 1           2  I am a student who is learning to code       No  Less than once per year  The quality of OSS and closed source software ...      Not employed, but looking for work  Bosnia and Herzegovina  Yes, full-time  Secondary school (e.g. American high school, G...            NaN  Taken an online course in programming or softw...     NaN  Developer, desktop or enterprise applications;...       NaN         17          NaN       NaN    NaN      NaN      NaN     NaN  I am actively looking for a job  I've never had a job     NaN      NaN  Financial performance or funding status of the...  Something else changed (education, award, medi...            NaN          NaN        NaN      NaN            NaN          NaN      NaN           NaN        NaN     NaN    NaN     NaN         NaN       NaN         NaN          NaN              C++;HTML/CSS;Python                      C++;HTML/CSS;JavaScript;SQL                NaN                  MySQL            Windows                  Windows
#
#   WebFrameWorkedWith WebFrameDesireNextYear MiscTechWorkedWith MiscTechDesireNextYear                  DevEnviron    OpSys               Containers BlockchainOrg                                       BlockchainIs BetterLife                                  ITperson OffOn SocialMedia Extraversion ScreenName SOVisit1st                      SOVisitFreq                                          SOVisitTo        SOFindAnswer                     SOTimeSaved  SOHowMuchTime SOAccount                       SOPartFreq                                             SOJobs                             EntTeams         SOComm                            WelcomeChange                                       SONewContent   Age Gender Trans                Sexuality Ethnicity Dependents           SurveyLength                  SurveyEase
# 0       Django;Flask           Flask;jQuery            Node.js                Node.js  IntelliJ;Notepad++;PyCharm  Windows  I do not use containers           NaN                                                NaN        Yes  Fortunately, someone else has that title   Yes     Twitter       Online   Username       2017  A few times per month or weekly  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  31-60 minutes        No                              NaN  No, I didn't know that Stack Overflow had a jo...  No, and I don't know what those are        Neutral  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  14.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult
# 1             Django                 Django                NaN                    NaN                Atom;PyCharm  Windows  I do not use containers           NaN  Useful across many domains and could change ma...        Yes                                       Yes   Yes   Instagram       Online   Username       2017            Daily or almost daily  Find answers to specific questions;Learn how t...  3-5 times per week  Stack Overflow was much faster  11-30 minutes       Yes  A few times per month or weekly  No, I knew that Stack Overflow had a job board...  No, and I don't know what those are  Yes, somewhat  Just as welcome now as I felt last year  Tech articles written by other developers;Indu...  19.0    Man    No  Straight / Heterosexual       NaN         No  Appropriate in length  Neither easy nor difficult

# %% [markdown]
# ## Prepare Data

# %%
df_2019_satisfaction = df_2019[['CareerSat', 'JobSat', 'Employment', 'LanguageWorkedWith' , 'Country']]

# %%
df_2019_satisfaction = df_2019_satisfaction[df_2019_satisfaction.Employment == "Employed full-time"]
df_2019_satisfaction = df_2019_satisfaction.dropna(axis=0)
df_2019_satisfaction['LanguageWorkedWith'] = df_2019_satisfaction['LanguageWorkedWith'].fillna('missing')
df_2019_satisfaction.head()  
df_2019_satisfaction.count()
# Out:
# CareerSat             60706
# JobSat                60706
# Employment            60706
# LanguageWorkedWith    60706
# Country               60706
# dtype: int64

# %%
print(60706/88883)
# Out:
# 0.6829877479383009

# %% [markdown]
# 0.6829877479383009
#
# Interestingly, there are about 60706 responses for 88883 total people. So about 28177 are either not employed full time or did not answer. I think we still have a significant amount to determine an well represented answer. Only about 1/4 of the data is missing and being employed full time means they are serious about coding, are fully committed and act professional. Other factors and distractions could influence happiness, i.e. people not full time can take a break or enjoy other activities.

# %%
df_2019_satisfaction_country = df_2019_satisfaction[df_2019_satisfaction.Country.isin(df_country_list)]

# %% [markdown]
# ## Data Understanding

# %%
df_2019_satisfaction_country.head(10)
# Out:
#                 CareerSat                              JobSat          Employment                                 LanguageWorkedWith             Country
# 3          Very satisfied                  Slightly satisfied  Employed full-time                                C;C++;C#;Python;SQL       United States
# 5          Very satisfied                  Slightly satisfied  Employed full-time                                         Java;R;SQL              Canada
# 9   Slightly dissatisfied               Slightly dissatisfied  Employed full-time                      C#;Go;JavaScript;Python;R;SQL               India
# 12         Very satisfied                      Very satisfied  Employed full-time  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...       United States
# 13         Very satisfied                      Very satisfied  Employed full-time                                                C++             Germany
# 15         Very satisfied                  Slightly satisfied  Employed full-time  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...      United Kingdom
# 16     Slightly satisfied  Neither satisfied nor dissatisfied  Employed full-time  Bash/Shell/PowerShell;HTML/CSS;JavaScript;Type...           Australia
# 17     Slightly satisfied                      Very satisfied  Employed full-time                                           Python;R  Russian Federation
# 18      Very dissatisfied                      Very satisfied  Employed full-time         C#;HTML/CSS;Java;JavaScript;SQL;TypeScript              Brazil
# 21     Slightly satisfied                   Very dissatisfied  Employed full-time  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...       United States

# %%
# Count the technology usage in each country, return a nested dictionary 
# in the form: {countyname: {tech1: count1, tech2: count2, ....}, .......}
def getSatisfactionStatistics(df):
    """ Given the dataframe, counting the technology usage for each country
    
    Args:
        df: dataframe
        tech: Language, Database, Platform, or Framework
    
    Returns:
        A dictionary containing the technology usage for each country
        
    """
    statistics = {}
    JobSat='JobSat'
    for index, row in df[['Country', JobSat]].iterrows():
        # add countries to the list if not exists
        if row['Country'] not in statistics:
            statistics[row['Country']] = {}
        # Technology count
        if row[JobSat] is not np.nan:
            for tar in row[JobSat].split(';'):
                statistics[row['Country']][tar] = statistics[row['Country']].get(tar, 0) + 1 

    return statistics

# %%
Satisfaction_statistics = getSatisfactionStatistics(df_2019_satisfaction_country)

# %%
df_sat = dfWithRelativePreference(Satisfaction_statistics,df_country_list)
df_sat.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 33.6%, transparent 33.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 27.1%, transparent 27.1%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 29.4%, #d65f5f 29.4%, #d65f5f 42.4%, transparent 42.4%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.7%, #5fba7d 63.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 38.7%, #d65f5f 38.7%, #d65f5f 46.9%, transparent 46.9%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 3.9%, #d65f5f 3.9%, #d65f5f 46.0%, transparent 46.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 68.1%, #5fba7d 68.1%, #5fba7d 81.8%, transparent 81.8%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 62.7%, #5fba7d 62.7%, #5fba7d 74.7%, transparent 74.7%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 71.2%, #5fba7d 71.2%, #5fba7d 87.1%, transparent 87.1%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.9%, #5fba7d 67.9%, #5fba7d 81.7%, transparent 81.7%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 13.5%, #d65f5f 13.5%, #d65f5f 34.6%, transparent 34.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 29.0%, #d65f5f 29.0%, #d65f5f 33.6%, transparent 33.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 9.3%, #d65f5f 9.3%, #d65f5f 27.1%, transparent 27.1%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent -0.0%, #d65f5f -0.0%, #d65f5f 42.4%, transparent 42.4%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.7%, #5fba7d 63.7%, #5fba7d 80.6%, transparent 80.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.6%, #d65f5f 44.6%, #d65f5f 46.9%, transparent 46.9%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 46.0%, transparent 46.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 68.1%, #5fba7d 68.1%, #5fba7d 96.9%, transparent 96.9%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 62.7%, #5fba7d 62.7%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 71.2%, #5fba7d 71.2%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.9%, #5fba7d 67.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 34.6%, transparent 34.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.0%, #d65f5f 33.0%, #d65f5f 33.6%, transparent 33.6%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 6.0%, #d65f5f 6.0%, #d65f5f 27.1%, transparent 27.1%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 42.4%, #5fba7d 42.4%, #5fba7d 50.8%, transparent 50.8%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.7%, #5fba7d 63.7%, #5fba7d 66.5%, transparent 66.5%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #5fba7d 46.9%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.0%, #5fba7d 46.0%, #5fba7d 99.0%, transparent 99.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 68.1%, #5fba7d 68.1%, #5fba7d 100.0%, transparent 100.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 62.7%, #5fba7d 62.7%, #5fba7d 64.0%, transparent 64.0%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 70.8%, #d65f5f 70.8%, #d65f5f 71.2%, transparent 71.2%);
#         }    #T_0f6e0cda_8d6f_11ea_8cba_00d86118075brow2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.9%, #5fba7d 67.9%, #5fba7d 93.5%, tra

# %%
### Data Modeling

# %%
def split_column(df, column):
    ''' Split column by ;,
        returns a splited series.
    '''
    
    df_copy = df
    column_series = df_copy[column].apply(lambda x: x.split(';'))
    
    return column_series

# Splitting the Data Frame by column into a Series. 
#q2['LanguageWorkedWith'] = q2['LanguageWorkedWith'].fillna('missing')
split_list_jobsat = split_column(df_2019_satisfaction, 'JobSat')
split_list_jobsat.head(10)
# Out:
# 2                     [Slightly satisfied]
# 3                     [Slightly satisfied]
# 4                  [Slightly dissatisfied]
# 5                     [Slightly satisfied]
# 8                     [Slightly satisfied]
# 9                  [Slightly dissatisfied]
# 12                        [Very satisfied]
# 13                        [Very satisfied]
# 15                    [Slightly satisfied]
# 16    [Neither satisfied nor dissatisfied]
# Name: JobSat, dtype: object

# %%
# again place data into a array that will then be transformed into a dictionary
def disarray(array_list):
    ''' Flat a nested list,
        returns a flat list.
    '''
    
    objects = []
    
    for row in array_list:
        for obj in row:
            objects.append(obj.strip())
    for elem in df_2019_satisfaction['JobSat']:
        objects.append(elem)
    return objects

# Flatting nested list objects.
list_worked_languages = disarray(split_list_jobsat)
# list_worked_languages

# %%
def group_list(data_list):
    ''' Group by count to a list,
        returns a result dict only for JobSat.
    '''
    
    grouped_list = dict(Counter(data_list))
    grouped_dict = [{'JobSat':key, 'Count': value} for key, value in grouped_list.items()]
    
    return grouped_dict

    
# Groping a list and creating a dict.
dict_worked_languages = group_list(list_worked_languages)
dict_worked_languages
# Out:
# [{'JobSat': 'Slightly satisfied', 'Count': 41902},
#  {'JobSat': 'Slightly dissatisfied', 'Count': 18664},
#  {'JobSat': 'Very satisfied', 'Count': 38286},
#  {'JobSat': 'Neither satisfied nor dissatisfied', 'Count': 14296},
#  {'JobSat': 'Very dissatisfied', 'Count': 8264}]

# %%
def create_dataframe(data_dicts): #column1, column2):
    ''' Input a dictionary list
        returns a pandas dataframe
    '''
    
    
    df1 = pd.DataFrame.from_dict(data_dicts)


    
    return df1

# Creating a Data Frame appending the data.
worked_jobsat = create_dataframe(dict_worked_languages)
worked_jobsat
# Out:
#    Count                              JobSat
# 0  41902                  Slightly satisfied
# 1  18664               Slightly dissatisfied
# 2  38286                      Very satisfied
# 3  14296  Neither satisfied nor dissatisfied
# 4   8264                   Very dissatisfied

# %%
# Get job Satisfaction Categies Counted
top_5_job_sat = worked_jobsat.sort_values(by=['Count'], ascending=False).head(10)['JobSat'].unique()


jobsat_chart = worked_jobsat[worked_jobsat['JobSat'].isin(top_5_job_sat)]
jobsat_chart
# Out:
#    Count                              JobSat
# 0  41902                  Slightly satisfied
# 1  18664               Slightly dissatisfied
# 2  38286                      Very satisfied
# 3  14296  Neither satisfied nor dissatisfied
# 4   8264                   Very dissatisfied

# %% [markdown]
#  ## Evaluate the Results

# %%
# Figure 3 — Number of Job Satisfaction Category Totals 
plt.figure(figsize=(14,8))
sns.barplot(x = 'Count', 
            y = 'JobSat',
            data = jobsat_chart.sort_values(by='Count'))
plt.xlabel("Count", fontsize = 14)
plt.ylabel("Job Satisfation Type", fontsize = 14)
plt.legend(fontsize='x-large', title_fontsize='40')
plt.title('Number of Job Satisfaction Category Totals', size = 16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Get the top 5 job Satisfaction Categies Counted
top_5_job_sat = worked_jobsat.sort_values(by=['Count'], ascending=False).head(10)['JobSat'].unique()

jobsat_chart = worked_jobsat[worked_jobsat['JobSat'].isin(top_5_job_sat)]
jobsat_chart
# Out:
#    Count                              JobSat
# 0  41902                  Slightly satisfied
# 1  18664               Slightly dissatisfied
# 2  38286                      Very satisfied
# 3  14296  Neither satisfied nor dissatisfied
# 4   8264                   Very dissatisfied

# %% [markdown]
# ## Result

# %%
explode = (0.1, 0.1, 1, 0.1, 0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(jobsat_chart.Count, explode=explode, labels=jobsat_chart.JobSat, autopct='%1.1f%%',
        shadow=True, startangle=90 , radius = 2)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *** based on above ~ 32 % of developers are satisfied and 34 % are slightly satisfied which concludes that Developer working in software industries are satisfy with there job  ***

# %% [markdown]
# # What should be My Appropriate budget to pay for developers ?

# %% [markdown]
# ## Prepare Data

# %%
df_2019_salaries = df_2019[['DevType', 'Country','ConvertedComp']]

for column in df_2019_salaries.columns.tolist():
    col_desc = df_2019_schema[df_2019_schema['Column']==column]['QuestionText'].iloc[0]
    print(col_desc)
# Out:
# Which of the following describe you? Please select all that apply.
# In which country do you currently reside?
# Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.

# %% [markdown]
# ## Schema Questions
# - Which of the following describe you? Please select all that apply.
# - In which country do you currently reside?
# - Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.

# %%
# Lets check for missing values in salaries_df
df_2019_salaries.isnull().sum()
# Out:
# DevType           7548
# Country            132
# ConvertedComp    33060
# dtype: int64

# %%
# salaries_df missing values in %
round((df_2019_salaries.isnull().sum()/df_2019_salaries.shape[0])*100,1)
# Out:
# DevType           8.5
# Country           0.1
# ConvertedComp    37.2
# dtype: float64

# %% [markdown]
# Insight
#
# it seems that a large number of developers do not reveal their salaries, and this could be due to privacy concerns.
#
# To assess the pay for developers, we will make use of salaries distribution by country. This allows us to compare like with like.

# %% [markdown]
# ## Data Understanding

# %%
# drop rows with missing values from salaries df
df_2019_salaries_clean = df_2019_salaries.dropna().reset_index()
df_2019_salaries_clean.head()
# Out:
#    index                                            DevType        Country  ConvertedComp
# 0      2  Designer;Developer, back-end;Developer, front-...       Thailand         8820.0
# 1      3                              Developer, full-stack  United States        61000.0
# 2      5  Data or business analyst;Data scientist or mac...         Canada       366420.0
# 3      8  Database administrator;Developer, back-end;Dev...    New Zealand        95179.0
# 4      9  Data or business analyst;Data scientist or mac...          India        13293.0

# %%
df_2019_salaries_clean.Country.value_counts().reset_index().head(12)
# Out:
#                  index  Country
# 0        United States    14756
# 1       United Kingdom     3967
# 2                India     3953
# 3              Germany     3734
# 4               Canada     2225
# 5               France     1619
# 6               Brazil     1395
# 7               Poland     1307
# 8            Australia     1233
# 9                Spain     1189
# 10         Netherlands     1184
# 11  Russian Federation     1095

# %% [markdown]
# ## Evaluate the Results

# %%
# now lets plot salary distributions for the top 20 countries

fig = plt.figure(figsize=(20,10))

countries = df_2019_salaries_clean['Country'].value_counts().sort_values(ascending=False)[:9].index.tolist()

for i,country in enumerate(countries):
    plt.subplot(3,3,i+1)
    temp_salaries = df_2019_salaries_clean.loc[df_2019_salaries_clean['Country']==country,'ConvertedComp']

    ax = temp_salaries.plot(kind='kde')
    ax.axvline(temp_salaries.mean(), linestyle = '-', color = 'black')
    ax.text((temp_salaries.mean() + 1500), (float(ax.get_ylim()[1])*0.55), 'mean = $ ' + str(round(temp_salaries.mean(),0)), fontsize = 12)
    ax.set_xlabel('Annual Salary in USD')
    ax.set_xlim(-temp_salaries.mean(),temp_salaries.mean()+2*temp_salaries.std())
    
    ax.set_title('Annual Salary Distribution in {}'.format(country))

plt.tight_layout()
plt.savefig('developer_salaries_by_country.png',bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *** from above we can conclude that in India is more cheaper than brazil , Poland and other countries.***
